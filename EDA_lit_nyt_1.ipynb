# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
from collections import Counter
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Литрес

# %% [markdown]
# Рассмотрим датасет, полученный скрейпингом с сайта Литрес и обогращенный при помощи api гугл книг

# %%
df1 = pd.read_csv("google_x_litres_final.csv")
df1.head()
# Out:
#    Unnamed: 0.1       id_book               categories        publisher  \
# 0             0  1Y11EQAAQBAJ              ['Fiction']  ЛитРес, SelfPub
# 1             1  Cb-UEAAAQBAJ  ['Young Adult Fiction']  ЛитРес, SelfPub
# 2             2           NaN                      NaN              NaN
# 3             3  p4_kzgEACAAJ                      NaN              Ast
# 4             4  1Y11EQAAQBAJ              ['Fiction']  ЛитРес, SelfPub
#
#                                          description  print_type  page_count  \
# 0  Он был моей единственной любовью. Плохой парен...         NaN       582.0
# 1  Я вижу его каждый день в окне дома напротив. О...         NaN       611.0
# 2                                                NaN         NaN         NaN
# 3                                                NaN         NaN       576.0
# 4  Он был моей единственной любовью. Плохой парен...         NaN       582.0
#
#   language country   saleability is_ebook  retail_price currency_code  \
# 0       ru      NL      FOR_SALE     True          2.70           EUR
# 1       ru      NL      FOR_SALE     True          2.22           EUR
# 2      NaN     NaN           NaN      NaN           NaN           NaN
# 3       ru      NL  NOT_FOR_SALE    False           NaN           NaN
# 4       ru      NL      FOR_SALE     True          2.70           EUR
#
#   viewability public_domain epub_avaliable pdf_avaliable  Unnamed: 0  \
# 0     PARTIAL         False           True          True           0
# 1     PARTIAL         False           True          True           1
# 2         NaN           NaN            NaN           NaN           2
# 3    NO_PAGES         False          False         False           3
# 4     PARTIAL         False           True          True           4
#
#                        title          author isbn  pages  publication_year  \
# 0  По осколкам твоего сердца      Анна Джейн  NaN  500.0            2025.0
# 1  Твое сердце будет разбито      Анна Джейн  NaN  510.0            2022.0
# 2        Фейерверк на ладони  Ольга Назарова  NaN  430.0            2026.0
# 3         Проект «Аве Мария»      Энди Вейер  NaN   21.0            2021.0
# 4  По осколкам твоего сердца      Анна Джейн  NaN   14.0            2022.0
#
#    rating  reviews_count  price currency age_restriction  \
# 0     4.9         3530.0  229.0      RUB             16+
# 1     4.8         7228.0  199.0      RUB             16+
# 2     4.9          139.0  189.0      RUB             16+
# 3     4.8         2117.0  529.0      RUB             16+
# 4     4.8          921.0  749.0      RUB             16+
#
#                                               genres  \
# 0  Литрес Авторы, От ненависти до любви, Первая л...
# 1  Литрес Авторы, Любовь и ненависть, Молодежные ...
# 2  Антистресс, Ироничная проза, Книги для души, К...
# 3  Авантюрные приключения, Близкое будущее, Заруб...
# 4  Young adult, Книги о подростках, Любовь и нена...
#
#                             publisher.1  \
# 0                Правообладатель: Автор
# 1                Правообладатель: Автор
# 2                Правообладатель: Автор
# 3            Правообладатель: Аудио-ЛАУ
# 4  Правообладатель: Издательство CLEVER
#
#                                              formats  \
# 0  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 1  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 2  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 3                                    m4b,, mp3,, zip
# 4                                    m4b,, mp3,, zip
#
#                                                  url  price_numeric  \
# 0  https://www.litres.ru/book/anna-dzheyn/po-osko...          229.0
# 1  https://www.litres.ru/book/anna-dzheyn/tvoe-se...          199.0
# 2  https://www.litres.ru/book/olga-stanislavovna-...          189.0
# 3  https://www.litres.ru/audiobook/endi-veyer/pro...          529.0
# 4  https://www.litres.ru/audiobook/anna-dzheyn/po...          749.0
#
#    rating_numeric  pages_numeric  reviews_numeric
# 0             4.9          500.0           3530.0
# 1             4.8          510.0           7228.0
# 2             4.9          430.0            139.0
# 3             4.8           21.0           2117.0
# 4             4.8           14.0            921.0

# %%
df1.dtypes
# Out:
# Unnamed: 0.1          int64
# id_book              object
# categories           object
# publisher            object
# description          object
# print_type          float64
# page_count          float64
# language             object
# country              object
# saleability          object
# is_ebook             object
# retail_price        float64
# currency_code        object
# viewability          object
# public_domain        object
# epub_avaliable       object
# pdf_avaliable        object
# Unnamed: 0            int64
# title                object
# author               object
# isbn                 object
# pages               float64
# publication_year    float64
# rating              float64
# reviews_count       float64
# price               float64
# currency             object
# age_restriction      object
# genres               object
# publisher.1          object
# formats              object
# url                  object
# price_numeric       float64
# rating_numeric      float64
# pages_numeric       float64
# reviews_numeric     float64
# dtype: object

# %% [markdown]
# Удалим заведомо ненужные для анализа столбцы

# %%
df1 = df1.drop(columns=["Unnamed: 0.1", "Unnamed: 0", "id_book", "price_numeric", "rating_numeric", "pages_numeric", "reviews_numeric"])

# %%
df1.shape
# Out:
# (10070, 29)

# %% [markdown]
# Переставим столбцы в более логичном для анализа порядке и переименуем некоторые столбцы для избежания разночтений

# %%
df1 = df1[["title", "author", "isbn", "rating", "reviews_count", "price", "currency", "publication_year", "pages", "age_restriction",
          "genres", "publisher.1", "formats", "url", "categories", "publisher", "description", "print_type", "page_count", "language", "country",
          "saleability", "is_ebook", "retail_price", "currency_code", "viewability", "public_domain", "epub_avaliable", "pdf_avaliable"]]

df1 = df1.rename(columns={"publisher.1":"lit_publisher", "publisher":"gb_publisher", "pages":"lit_pages", "page_count":"gb_pages"})

# %% [markdown]
# Рассмотрим полные дубликаты

# %%
n_duplicates = df1.duplicated(keep=False)
df1[n_duplicates].head(10)
# Out:
#                                                   title             author  \
# 647                                   Влюбленная ведьма         Анна Джейн
# 648                                   Влюбленная ведьма         Анна Джейн
# 719                        Звездная Кровь – 2. Фригольд    Роман Прокофьев
# 720                        Звездная Кровь – 2. Фригольд    Роман Прокофьев
# 1710                                           Сквотеры          Влад Лей,
# 1711                                       Черный север  Татьяна Солодкова
# 1714  Джон Стрелеки. Кафе на краю земли. Комплект кн...   Джон П. Стрелеки
# 1739                          ГКР-10: Исход Забытых Душ       Дем Михайлов
# 1752                     Ложится мгла на старые ступени  Александр Чудаков
# 1753                     Ложится мгла на старые ступени  Александр Чудаков
#
#                    isbn  rating  reviews_count  price currency  \
# 647                 NaN     4.9         3536.0  179.0      RUB
# 648                 NaN     4.9         3536.0  179.0      RUB
# 719                 NaN     4.9         2594.0  159.0      RUB
# 720                 NaN     4.9         2594.0  159.0      RUB
# 1710                NaN     4.9          129.0  399.0      RUB
# 1711                NaN     5.0          192.0  229.0      RUB
# 1714  978-5-04-197463-3     4.8           45.0    NaN      RUB
# 1739                NaN     4.8           42.0  176.0      RUB
# 1752  978-5-389-22585-5     4.7          200.0  549.0      RUB
# 1753  978-5-389-22585-5     4.7          200.0  549.0      RUB
#
#       publication_year  lit_pages age_restriction  \
# 647             2022.0      500.0             16+
# 648             2022.0      500.0             16+
# 719             2023.0      290.0             18+
# 720             2023.0      290.0             18+
# 1710            2025.0        8.0             16+
# 1711            2025.0      300.0             16+
# 1714               NaN      404.0             16+
# 1739            2025.0       60.0             16+
# 1752            2000.0      721.0             18+
# 1753            2000.0      721.0             18+
#
#                                                  genres  \
# 647   Литрес Авторы, Любовь и ненависть, Новый год, ...
# 648   Литрес Авторы, Любовь и ненависть, Новый год, ...
# 719   LitRPG, Боевая фантастика, Героическое фэнтези...
# 720   LitRPG, Боевая фантастика, Героическое фэнтези...
# 1710  Боевая фантастика, Боевики, Зомби, Книги о при...
# 1711  Героическое фэнтези, Детективное фэнтези, Зимн...
# 1714  Вдохновляющие книги, Жизненные ценности, Заруб...
# 1739  LitRPG, Литрес Авторы, Черновик, Юмористическа...
# 1752  Основано на реальных событиях, Портрет эпохи, ...
# 1753  Основано на реальных событиях, Портрет эпохи, ...
#
#                              lit_publisher  \
# 647                 Правообладатель: Автор
# 648                 Правообладатель: Автор
# 719                 Правообладатель: Автор
# 720                 Правообладатель: Автор
# 1710  Правообладатели: ЛитРес: чтец, Автор
# 1711                Правообладатель: Автор
# 1714                Правообладатель: Эксмо
# 1739                Правообладатель: Автор
# 1752               Правообладатель: Азбука
# 1753               Правообладатель: Азбука
#
#                                                 formats  \
# 647   epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 648   epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 719   epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 720   epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 1710                                    m4b,, mp3,, zip
# 1711  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 1714  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 1739                                              текст
# 1752  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 1753  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
#
#                                                     url            categories  \
# 647   https://www.litres.ru/book/anna-dzheyn/vlublen...  ['College students']
# 648   https://www.litres.ru/book/anna-dzheyn/vlublen...  ['College students']
# 719   https://www.litres.ru/book/roman-urevich-proko...           ['Fiction']
# 720   https://www.litres.ru/book/roman-urevich-proko...           ['Fiction']
# 1710  https://www.litres.ru//audiobook/aleksandr-gro...           ['Fiction']
# 1711  https://www.litres.ru//book/tatyana-solodkova/...           ['Fiction']
# 1714  https://www.litres.ru//book/john-strelecky/dzh...        ['Psychology']
# 1739  https://www.litres.ru//book/dem-mihaylov/gkr-1...           ['Fiction']
# 1752  https://www.litres.ru//book/aleksandr-chudakov...           ['Fiction']
# 1753  https://www.litres.ru//book/aleksandr-chudakov...           ['Fiction']
#
#          gb_publisher                                        description  \
# 647               NaN                                                NaN
# 648               NaN                                                NaN
# 719            ЛитРес  Оказывается, это не Земля.И не другая планета....
# 720            ЛитРес  Оказывается, это не Земля.И не другая планета....
# 1710  ЛитРес, SelfPub  Небольшой поселок, в котором осели пережившие ...
# 1711  ЛитРес, SelfPub  Прошло три года с тех пор, как в Реонерии была...
# 1714           ЛитРес  Комплект из четырех культовых книг Джона П. Ст...
# 1739           ЛитРес  Прошли столетья с тех пор как отгремели чудови...
# 1752           Litres  Александр Чудаков (1938–2005), выдающийся росс...
# 1753           Litres  Александр Чудаков (1938–2005), выдающийся росс...
#
#       print_type  gb_pages language country   saleability is_ebook  \
# 647          NaN       0.0       ru      NL  NOT_FOR_SALE    False
# 648          NaN       0.0       ru      NL  NOT_FOR_SALE    False
# 719          NaN     305.0       ru      NL      FOR_SALE     True
# 720          NaN     305.0       ru      NL      FOR_SALE     True
# 1710         NaN     308.0       ru      NL      FOR_SALE     True
# 1711         NaN     382.0       ru      NL      FOR_SALE     True
# 1714         NaN     517.0       ru      NL      FOR_SALE     True
# 1739         NaN     291.0       ru      NL      FOR_SALE     True
# 1752         NaN     745.0       ru      NL  NOT_FOR_SALE    False
# 1753         NaN     745.0       ru      NL  NOT_FOR_SALE    False
#
#       retail_price currency_code viewability public_domain epub_avaliable  \
# 647            NaN           NaN    NO_PAGES         False          False
# 648            NaN           NaN    NO_PAGES         False          False
# 719           2.16           EUR     PARTIAL         False           True
# 720           2.16           EUR     PARTIAL         False           True
# 1710          2.70           EUR     PARTIAL         False           True
# 1711          2.81           EUR     PARTIAL         False           True
# 1714         14.30           EUR     PARTIAL         False           True
# 1739          1.95           EUR     PARTIAL         False           True
# 1752           NaN           NaN     PARTIAL         False           True
# 1753           NaN           NaN     PARTIAL         False           True
#
#      pdf_avaliable
# 647          False
# 648          False
# 719           True
# 720           True
# 1710          True
# 1711          True
# 1714          True
# 1739          True
# 1752          True
# 1753          True

# %% [markdown]
# Можно заметить, что многие полные дубликаты идут с последовательными номерами (как например 647 и 647 или 1752 и 1753). Это было замечено на этапе парсинга, когда при загрузке некоторых страниц одна и та же книга считалась первой книгой страницы i и последней книгой страницы i-1. Вероятно, это происходило из-за попытки Литреса динамтчески подгружать следующую страницу.
#
# Другие дубликаты возникли из-за неустойчивости рекомендательной выдачи. Так как датасет парсился по частям, в разное время и разными людьми, то одна и та же книга возникала в выдаче несколько раз и осталась при объединении - такие дубликаты можно спокойно удалить

# %%
df1 = df1.drop_duplicates()
df1.shape
# Out:
# (8910, 29)

# %% [markdown]
# Рассмотрим другой "тип" дубликатов. Дублирование одного и того же издания, но с разницами в каких-то полях. Тут посмотрим по url.

# %%
n_duplicates2 = df1.duplicated(subset=["url"], keep=False)
df1[n_duplicates2].sort_values("title").head(10)
# Out:
#                                                   title  \
# 9078  Will. Чему может научить нас простой парень, с...
# 9795  Will. Чему может научить нас простой парень, с...
# 6534                                       Адран в огне
# 6003                                       Адран в огне
# 7193         Академия Полуночников 2. На острие кинжала
# 7208         Академия Полуночников 2. На острие кинжала
# 6191                              Ангелочек для бывшего
# 6708                              Ангелочек для бывшего
# 2608  Английский для начинающих. Повышаем уровень A1...
# 2616  Английский для начинающих. Повышаем уровень A1...
#
#                             author               isbn  rating  reviews_count  \
# 9078                  Марк Мэнсон,                NaN     4.9         6345.0
# 9795                  Марк Мэнсон,                NaN     4.9         6346.0
# 6534              Влада Ольховская  978-5-535-00210-1     4.9          788.0
# 6003              Влада Ольховская  978-5-535-00210-1     4.9          787.0
# 7193  Дора Коуст (Любовь Огненная)                NaN     4.9          710.0
# 7208  Дора Коуст (Любовь Огненная)                NaN     4.9          710.0
# 6191                   Алла Ларина                NaN     4.8           67.0
# 6708                   Алла Ларина                NaN     4.8           69.0
# 2608              Александр Бебрис  978-5-04-230826-0     5.0           15.0
# 2616              Александр Бебрис  978-5-04-230826-0     5.0           15.0
#
#       price currency  publication_year  lit_pages age_restriction  \
# 9078  712.0      RUB            2021.0       12.0             16+
# 9795  712.0      RUB            2021.0       12.0             16+
# 6534  209.9      RUB            2022.0      290.0             16+
# 6003  209.9      RUB            2022.0      290.0             16+
# 7193  199.0      RUB            2024.0      210.0             16+
# 7208  199.0      RUB            2024.0      210.0             16+
# 6191  159.0      RUB            2026.0       90.0             16+
# 6708  159.0      RUB            2026.0       90.0             16+
# 2608  677.0      RUB            2025.0      338.0             16+
# 2616  677.0      RUB            2025.0      338.0             16+
#
#                                                  genres  \
# 9078  Автобиографии, Биографии и мемуары, Вдохновляю...
# 9795  Автобиографии, Биографии и мемуары, Вдохновляю...
# 6534  Героическая фантастика, Дружба и верность, Ино...
# 6003  Героическая фантастика, Дружба и верность, Ино...
# 7193  Книги про волшебниковЛитрес АвторыЛюбовное фэн...
# 7208  Книги про волшебников, Литрес Авторы, Любовное...
# 6191  Встреча через годы, Дети, Короткие любовные ро...
# 6708  Встреча через годы, Дети, Короткие любовные ро...
# 2608  Авторские методикиАнглийский для начинающихАнг...
# 2616  Авторские методики, Английский для начинающих,...
#
#                           lit_publisher  \
# 9078             Правообладатель: Эксмо
# 9795             Правообладатель: Эксмо
# 6534  Правообладатель: Влада Ольховская
# 6003  Правообладатель: Влада Ольховская
# 7193             Правообладатель: Автор
# 7208             Правообладатель: Автор
# 6191             Правообладатель: Автор
# 6708             Правообладатель: Автор
# 2608             Правообладатель: Эксмо
# 2616             Правообладатель: Эксмо
#
#                                                 formats  \
# 9078                              m4b,, mp3,, pdf,, zip
# 9795                              m4b,, mp3,, pdf,, zip
# 6534  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 6003  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 7193  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 7208  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 6191  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 6708  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 2608                                                pdf
# 2616                                                pdf
#
#                                                     url  \
# 9078  https://www.litres.ru/audiobook/mark-menson/wi...
# 9795  https://www.litres.ru/audiobook/mark-menson/wi...
# 6534  https://www.litres.ru//book/vlada-olhovskaya/a...
# 6003  https://www.litres.ru//book/vlada-olhovskaya/a...
# 7193  https://www.litres.ru/book/lubov-ognennaya-211...
# 7208  https://www.litres.ru/book/lubov-ognennaya-211...
# 6191  https://www.litres.ru//book/alla-larina/angelo...
# 6708  https://www.litres.ru//book/alla-larina/angelo...
# 2608  https://www.litres.ru/book/aleksandr-bebris-32...
# 2616  https://www.litres.ru/book/aleksandr-bebris-32...
#
#                          categories     gb_publisher  \
# 9078  ['Biography & Autobiography']           ЛитРес
# 9795  ['Biography & Autobiography']           ЛитРес
# 6534                    ['Fiction']           ЛитРес
# 6003                    ['Fiction']           ЛитРес
# 7193                    ['Fiction']  ЛитРес, SelfPub
# 7208                    ['Fiction']  ЛитРес, SelfPub
# 6191                            NaN              NaN
# 6708                            NaN              NaN
# 2608             ['Language Study']           ЛитРес
# 2616             ['Language Study']           ЛитРес
#
#                                             description  print_type  gb_pages  \
# 9078  «Я всегда считал себя трусом. Большая часть мо...         NaN     595.0
# 9795  «Я всегда считал себя трусом. Большая часть мо...         NaN     595.0
# 6534  Когда стало известно о падении «Близкого гориз...         NaN     294.0
# 6003  Когда стало известно о падении «Близкого гориз...         NaN     294.0
# 7193  Годами мы с мамой скрывались в надежде, что ОН...         NaN     246.0
# 7208  Годами мы с мамой скрывались в надежде, что ОН...         NaN     246.0
# 6191                                                NaN         NaN       NaN
# 6708                                                NaN         NaN       NaN
# 2608  «Выучить английский может каждый!»Сколько раз ...         NaN     274.0
# 2616  «Выучить английский может каждый!»Сколько раз ...         NaN     274.0
#
#      language country saleability is_ebook  retail_price currency_code  \
# 9078       ru      NL    FOR_SALE     True          4.48           EUR
# 9795       ru      NL    FOR_SALE     True          4.48           EUR
# 6534       ru      NL    FOR_SALE     True          2.85           EUR
# 6003       ru      NL    FOR_SALE     True          2.85           EUR
# 7193       ru      NL    FOR_SALE     True          2.70           EUR
# 7208       ru      NL    FOR_SALE     True          2.70           EUR
# 6191      NaN     NaN         NaN      NaN           NaN           NaN
# 6708      NaN     NaN         NaN      NaN           NaN           NaN
# 2608       ru      NL    FOR_SALE     True          6.55           EUR
# 2616       ru      NL    FOR_SALE     True          6.55           EUR
#
#      viewability public_domain epub_avaliable pdf_avaliable
# 9078     PARTIAL         False           True          True
# 9795     PARTIAL         False           True          True
# 6534     PARTIAL         False           True          True
# 6003     PARTIAL         False           True          True
# 7193     PARTIAL         False           True          True
# 7208     PARTIAL         False           True          True
# 6191         NaN           NaN            NaN           NaN
# 6708         NaN           NaN            NaN           NaN
# 2608     PARTIAL         False          False          True
# 2616     PARTIAL         False          False          True

# %% [markdown]
# Отличается кол-во оценок :) <br>
# Пока мы парсили, кто-то успел поставить ещё одну оценку на книгу :)) <br>
#
# Отсортируем их так, чтоб удалять строки с меньшим кол-вом отзывов. И удалим дубликаты

# %%
df1 = df1.sort_values("reviews_count").drop_duplicates(keep="last")
df1 = df1.sort_index().reset_index(drop=True)
df1.shape
# Out:
# (8910, 29)

# %% [markdown]
# ### Удаление дубликатов, заполнение пропусков, выбор признаков

# %% [markdown]
# #### `title`

# %%
df1["title"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Пропусков в названиях нет

# %%
pd.DataFrame(df1["title"].value_counts()).head(6)
# Out:
#                                                     count
# title
# Проверка браузера перед переходом на www.litres.ru     40
# Граф Монте-Кристо                                       5
# 1984                                                    5
# Скорбь Сатаны                                           4
# Улей. Трилогия                                          4
# Сумерки                                                 4

# %% [markdown]
# Посмотрим топ-5 самых часто встречающихся произведений в различных изданиях. Оказалось, что чаще всего люди читают Проверку браузера перед переходом - удалим из датасета эти строки

# %%
df1 = df1.drop(index = df1[df1["title"] == "Проверка браузера перед переходом на www.litres.ru"].index)
df1 = df1.reset_index(drop = True)
df1.shape
# Out:
# (8870, 29)

# %% [markdown]
# #### `author`

# %%
df1["author"].isna().sum()
# Out:
# np.int64(2)

# %% [markdown]
# В столбце с автором есть 2 пустые строки - посмотрим на эти строки.

# %%
df1[df1["author"].isna()]
# Out:
#                                    title author isbn  rating  reviews_count  \
# 4181  Не удается получить доступ к сайту    NaN  NaN     NaN            NaN
# 6321                 Соединение прервано    NaN  NaN     NaN            NaN
#
#       price currency  publication_year  lit_pages age_restriction genres  \
# 4181    NaN      RUB               NaN        NaN             NaN    NaN
# 6321    NaN      RUB               NaN        NaN             NaN    NaN
#
#      lit_publisher formats                                                url  \
# 4181           NaN   текст  https://www.litres.ru//book/karina-demina/grom...
# 6321           NaN   текст  https://www.litres.ru//audiobook/dana-heys/ide...
#
#      categories gb_publisher description  print_type  gb_pages language  \
# 4181        NaN          NaN         NaN         NaN       NaN      NaN
# 6321        NaN          NaN         NaN         NaN       NaN      NaN
#
#      country saleability is_ebook  retail_price currency_code viewability  \
# 4181     NaN         NaN      NaN           NaN           NaN         NaN
# 6321     NaN         NaN      NaN           NaN           NaN         NaN
#
#      public_domain epub_avaliable pdf_avaliable
# 4181           NaN            NaN           NaN
# 6321           NaN            NaN           NaN

# %% [markdown]
# Прекрасные произведения, достойные своей славы - удалим эти строки.

# %%
df1 = df1.drop(index = df1[df1["author"].isna()].index)
df1 = df1.reset_index(drop = True)
df1.shape
# Out:
# (8868, 29)

# %% [markdown]
# Посмотрим на топ 10 авторов

# %%
pd.DataFrame(df1["author"].value_counts()).head(10)
# Out:
#                    count
# author
# Серж Винтеркей        96
# Андрей Васильев       80
# Дмитрий Дорничев      60
# Серж Винтеркей,       59
# Стивен Кинг           55
# Роман Прокофьев       54
# Макс Глебов           53
# Ольга Назарова        52
# Михаил Атаманов       50
# Сергей Лукьяненко     50

# %% [markdown]
# Выходит, что некоторые авторы сохранились с запятыми. Нужно это поправить

# %%
df1["author"] = df1["author"].str.replace(",", "")
pd.DataFrame(df1["author"].value_counts()).head(10)
# Out:
#                          count
# author
# Серж Винтеркей             155
# Алекс Ключевской (Лёха)     95
# Андрей Васильев             81
# Дмитрий Дорничев            77
# Роман Прокофьев             56
# Стивен Кинг                 55
# Сергей Лукьяненко           53
# Макс Глебов                 53
# Ольга Назарова              52
# Михаил Атаманов             50

# %% [markdown]
# #### `isbn`

# %%
df1["isbn"].isna().sum()
# Out:
# np.int64(5874)

# %% [markdown]
# В этом столбце огромное количество пропусков. Но это ничего страшного. Отсутвие isbn указывает на то, что это издание было опубликовано через «Литрес самиздат». Сам по себе isbn не несёт сути для анализа, а вот его наличие/отсутвие может пригодиться.

# %%
df1["has_isbn"] = False
df1["has_isbn"] = df1["has_isbn"].where(df1["isbn"].isna(), True)
df1['isbn'] = df1["has_isbn"]
df1 = df1.drop(columns=["has_isbn"])
df1 = df1.rename(columns={"isbn":'has_isbn'})

# %% [markdown]
# #### `rating`, `reviews_count`, `price`, `currency`, `lit_pages`, `publication_year`

# %%
df1[["rating", "reviews_count", "price", "currency", "lit_pages", "publication_year"]].isna().sum()
# Out:
# rating                0
# reviews_count       153
# price               161
# currency              0
# lit_pages             0
# publication_year    465
# dtype: int64

# %%
df1[df1["rating"] == 0].shape
# Out:
# (153, 29)

# %%
pd.DataFrame(df1["currency"].value_counts()).head(10)
# Out:
#           count
# currency
# RUB        8868

# %% [markdown]
# У `rating` нет пропусков, если пока нет оценки этой книги, то её рейтинг равен 0.0 <br>
# У `reviews_count` 153 пропусков, как раз те 153 книги, у которых ещё нет рейтинга <br>
# У  `price` 161 пропуск, посмотрим на них позже <br>
# У `currency` пропусков нет, но всё значения столбца одинаковые - его можно удалить <br>
# У `lit_pages` пропусков нет, даже для аудиокниг, потому что для аудиокниг этот столбец показывает длительность аудиокниги в часах. Вообще, этот момент стоит поправить, когда мы научимся быстро отделять печатную книгу и аудиокнигу <br>
# У `publication_year` 465 пропусков, посмотрим на них позже

# %%
df1 = df1.drop(columns=["currency"])

# %%
df1[df1["price"].isna()].head(3)
# Out:
#                                                  title              author  \
# 378   Задача трех тел. Комплект из 3 романов Лю Цысиня           Лю Цысинь
# 524  Доказательная психосоматика со справочником. Ф...   Тимофей Кармацкий
# 584  Две жизни. Все части. Сборник в обновленной ре...  Конкордия Антарова
#
#      has_isbn  rating  reviews_count  price  publication_year  lit_pages  \
# 378      True     4.6           29.0    NaN            1861.0     1861.0
# 524      True     4.6           49.0    NaN            2025.0      403.0
# 584      True     4.8          362.0    NaN            2561.0     2561.0
#
#     age_restriction                                             genres  \
# 378             16+  Боевая фантастика, Виртуальная реальность, Вне...
# 524             16+  Альтернативная медицина, Болезни и способы их ...
# 584             16+  В поисках истины, Духовная литература, Духовна...
#
#                          lit_publisher  \
# 378             Правообладатель: Эксмо
# 524  Правообладатель: Издательство АСТ
# 584  Правообладатель: Издательство АСТ
#
#                                                formats  \
# 378  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 524  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 584  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
#
#                                                    url            categories  \
# 378  https://www.litres.ru/book/lu-cysin/zadacha-tr...           ['Fiction']
# 524  https://www.litres.ru/book/timofey-karmackiy/d...  ['Health & Fitness']
# 584  https://www.litres.ru/book/konkordiya-antarova...          ['Religion']
#
#                        gb_publisher  \
# 378                   ЛитРес, Эксмо
# 524  ЛитРес, ООО «Издательство АСТ»
# 584                     ЛитРес, АСТ
#
#                                            description  print_type  gb_pages  \
# 378  Задача трех телВ те времена, когда Китай переж...         NaN    1892.0
# 524  Подарочное издание хита «Доказательная психосо...         NaN     453.0
# 584  Книга «Две жизни» – мистический роман, который...         NaN    2660.0
#
#     language country   saleability is_ebook  retail_price currency_code  \
# 378       ru      NL      FOR_SALE     True         19.12           EUR
# 524       ru      NL      FOR_SALE     True          6.88           EUR
# 584       ru      NL  NOT_FOR_SALE    False           NaN           NaN
#
#     viewability public_domain epub_avaliable pdf_avaliable
# 378     PARTIAL         False           True          True
# 524     PARTIAL         False           True          True
# 584     PARTIAL         False           True          True

# %% [markdown]
# Изучение сайта Литреса показало, что книги из этой категории на данный момент имеют скидку на Литрес, поэтому их цена отмечена другим классом и не смогла заскрейпиться. Заполнить их числовыми значениями на данном этапе нельзя. Считать цену равной 0 в данном случае тоже крайне неверно, поэтому мы осмысленно и аргументированно оставляем пропуски Nan-ами

# %%
df1[df1["publication_year"].isna()].head(3)
# Out:
#                                         title            author  has_isbn  \
# 35          Чужая жена. Развод не устраивает!  Наталья Мамлеева     False
# 49  Чужая жена. Развод не устраивает! Книга 2  Наталья Мамлеева     False
# 52                         Тайна мыса Пицунда    Николай Свечин     False
#
#     rating  reviews_count  price  publication_year  lit_pages age_restriction  \
# 35     4.9          184.0  199.0               NaN      205.0             16+
# 49     4.9          152.0  199.0               NaN      211.0             16+
# 52     4.5          117.0  579.0               NaN        8.0             18+
#
#                                                genres  \
# 35  Властный герой, Вынужденный брак, Любовное фэн...
# 49  Властный герой, Вынужденный брак, Любовное фэн...
# 52  Исторические детективы, Остросюжетная литерату...
#
#                         lit_publisher  \
# 35  Правообладатель: Наталья Мамлеева
# 49  Правообладатель: Наталья Мамлеева
# 52  Правообладатель: Аудиокнига (АСТ)
#
#                                               formats  \
# 35  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 49  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 52                                    m4b,, mp3,, zip
#
#                                                   url   categories  \
# 35  https://www.litres.ru/book/natalya-mamleeva/ch...  ['Fiction']
# 49  https://www.litres.ru/book/natalya-mamleeva/ch...  ['Fiction']
# 52  https://www.litres.ru/audiobook/nikolay-svechi...  ['Fiction']
#
#      gb_publisher                                        description  \
# 35         ЛитРес  Ненавижу лорда Риатона! Маг смерти с тенью Дра...
# 49         ЛитРес  Богиня подарила мне второй шанс. Я оказалась в...
# 52  ЛитРес, Эксмо  НЕЗАКОННОЕ ПОТРЕБЛЕНИЕ НАРКОТИЧЕСКИХ СРЕДСТВ, ...
#
#     print_type  gb_pages language country saleability is_ebook  retail_price  \
# 35         NaN     226.0       ru      NL    FOR_SALE     True          2.70
# 49         NaN     233.0       ru      NL    FOR_SALE     True          2.70
# 52         NaN     303.0       ru      NL    FOR_SALE     True          6.44
#
#    currency_code viewability public_domain epub_avaliable pdf_avaliable
# 35           EUR     PARTIAL         False           True          True
# 49           EUR     PARTIAL         False           True          True
# 52           EUR     PARTIAL         False           True          True

# %% [markdown]
# В годах так же нужно рассмотреть "разумность" года. Нет ли у нас каких-то книг из будущего, итд

# %%
pd.DataFrame(df1["publication_year"].value_counts().sort_index()).head(5)
# Out:
#                   count
# publication_year
# 1000.0                1
# 1001.0                1
# 1005.0                1
# 1008.0                1
# 1010.0                1

# %%
pd.DataFrame(df1["publication_year"].value_counts().sort_index()).tail(5)
# Out:
#                   count
# publication_year
# 2561.0                1
# 2770.0                1
# 2799.0                1
# 3191.0                1
# 3388.0                2

# %% [markdown]
# Очевидно, что-то странное тут есть. Посмотрим на эти строки. Поставим границу "станности" в прошлое на 1750 год. В случае, если количество страниц в книге четырехзначное, то в некоторых случаях кол-во страниц ошибочно считалось годом написания. Найдем такие строки и поставим год на Nan

# %%
df1["publication_year"] = np.where(df1["publication_year"] == df1["lit_pages"], None, df1["publication_year"])

# %% [markdown]
# #### `age_restriction`, `genres`, `lit_publisher`

# %%
df1[["age_restriction", "genres", "lit_publisher"]].isna().sum()
# Out:
# age_restriction    293
# genres               0
# lit_publisher        0
# dtype: int64

# %% [markdown]
# Где пропуск `age_restriction`, там на литрес стоял 0+. Заполним пропуски 0. Аналогично приведем столбец к числовому формату

# %%
df1["age_restriction"] = df1["age_restriction"].str[:-1]

# %%
df1["age_restriction"] = df1["age_restriction"].fillna(0)
df1["age_restriction"] = df1["age_restriction"].astype(int)

# %%
arr = df1["genres"].str.lower().str.split(",").explode()
df1["genres"] = df1["genres"].str.lower()
genres_pool = ' '.join(arr.dropna())
word_counts = Counter(genres_pool.split())
word_counts_df = pd.DataFrame(word_counts.items(), columns=['genre', 'count']).sort_values("count", ascending=False)

# %% [markdown]
# Рассмотрим 10 самых популярных, полезных для анализа жанров. На литресе большинство жанров названы двумя словами "приключенческое фэнтези", "боевая фантастика", но с точки зрения OHE и дальнейшего анализа подобные жанры стоит кодировать отдельно прилагательным и существительным. Поэтому посмотрим на топ самых часто встречающихся слов и отберем 10 жанров.

# %%
word_counts_df.head(20)
# Out:
#            genre  count
# 83       фэнтези   6927
# 0         литрес   4278
# 36    фантастика   2887
# 12        романы   2688
# 11      любовные   2598
# 1         авторы   2374
# 66            на   2122
# 55     детективы   2057
# 29    литература   1830
# 65        только   1758
# 81     попаданцы   1717
# 13             и   1686
# 74             /   1426
# 10   современные   1402
# 141   магические   1317
# 42          миры   1291
# 35    зарубежная   1268
# 243   психология   1196
# 19         проза   1195
# 32   приключения   1143

# %% [markdown]
# Топ 10 осмысленных:
# 1. фэнтези
# 2. фантастика (фантастик)
# 3. романы (роман)
# 4. любовные	(любовн)
# 5. детективы (детектив)
# 6. попаданцы
# 7. магические (магическ)
# 8. зарубежная (зарубеж)
# 9. психология (психолог)
# 10. проза

# %%
genres10_rus = ["фэнтези", "фантасти", "роман", "любовн", "детектив", "попаданцы", "магическ", "зарубеж", "психолог", "проз"]
genres10_eng = ["fantasy", "scifi", "novel", "romance", "detective", "popad", "magic", "foreign", "psychology", "prose"]

for i in range(10):
    df1[f"genre_{genres10_eng[i]}"] = df1["genres"].apply(
        lambda x: genres10_rus[i] in x.lower() if isinstance(x, str) else False
    )

# %%
df1 = df1.drop(columns=["genres"])

# %%
pd.DataFrame(df1["lit_publisher"].value_counts()).head(10)
# Out:
#                                               count
# lit_publisher
# Правообладатель: Автор                         2539
# Правообладатель: Эксмо                         1342
# Правообладатель: Издательство АСТ               853
# Правообладатель: Азбука                         355
# Правообладатель: ИДДК                           252
# Правообладатель: 1С-Паблишинг                   228
# Правообладатели: ЛитРес: чтец, Автор            209
# Правообладатель: Альпина Диджитал               201
# Правообладатель: Аудиокнига (АСТ)               162
# Правообладатель: Манн, Иванов и Фербер (МИФ)    161

# %% [markdown]
# Уберем из столбца слова "Правообладатель"

# %%
df1["lit_publisher"] = df1["lit_publisher"].str.split(":").str[1]

# %%
df1.head()
# Out:
#                        title          author  has_isbn  rating  reviews_count  \
# 0  По осколкам твоего сердца      Анна Джейн     False     4.9         3530.0
# 1  Твое сердце будет разбито      Анна Джейн     False     4.8         7228.0
# 2        Фейерверк на ладони  Ольга Назарова     False     4.9          139.0
# 3         Проект «Аве Мария»      Энди Вейер     False     4.8         2117.0
# 4  По осколкам твоего сердца      Анна Джейн     False     4.8          921.0
#
#    price publication_year  lit_pages  age_restriction         lit_publisher  \
# 0  229.0           2025.0      500.0               16                 Автор
# 1  199.0           2022.0      510.0               16                 Автор
# 2  189.0           2026.0      430.0               16                 Автор
# 3  529.0           2021.0       21.0               16             Аудио-ЛАУ
# 4  749.0           2022.0       14.0               16   Издательство CLEVER
#
#                                              formats  \
# 0  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 1  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 2  epub,, fb2,, fb3,, ios.epub,, mobi,, pdf,, txt...
# 3                                    m4b,, mp3,, zip
# 4                                    m4b,, mp3,, zip
#
#                                                  url               categories  \
# 0  https://www.litres.ru/book/anna-dzheyn/po-osko...              ['Fiction']
# 1  https://www.litres.ru/book/anna-dzheyn/tvoe-se...  ['Young Adult Fiction']
# 2  https://www.litres.ru/book/olga-stanislavovna-...                      NaN
# 3  https://www.litres.ru/audiobook/endi-veyer/pro...                      NaN
# 4  https://www.litres.ru/audiobook/anna-dzheyn/po...              ['Fiction']
#
#       gb_publisher                                        description  \
# 0  ЛитРес, SelfPub  Он был моей единственной любовью. Плохой парен...
# 1  ЛитРес, SelfPub  Я вижу его каждый день в окне дома напротив. О...
# 2              NaN                                                NaN
# 3              Ast                                                NaN
# 4  ЛитРес, SelfPub  Он был моей единственной любовью. Плохой парен...
#
#    print_type  gb_pages language country   saleability is_ebook  retail_price  \
# 0         NaN     582.0       ru      NL      FOR_SALE     True          2.70
# 1         NaN     611.0       ru      NL      FOR_SALE     True          2.22
# 2         NaN       NaN      NaN     NaN           NaN      NaN           NaN
# 3         NaN     576.0       ru      NL  NOT_FOR_SALE    False           NaN
# 4         NaN     582.0       ru      NL      FOR_SALE     True          2.70
#
#   currency_code viewability public_domain epub_avaliable pdf_avaliable  \
# 0           EUR     PARTIAL         False           True          True
# 1           EUR     PARTIAL         False           True          True
# 2           NaN         NaN           NaN            NaN           NaN
# 3           NaN    NO_PAGES         False          False         False
# 4           EUR     PARTIAL         False           True          True
#
#    genre_fantasy  genre_scifi  genre_novel  genre_romance  genre_detective  \
# 0          False        False         True           True            False
# 1          False        False         True           True            False
# 2          False        False        False          False            False
# 3          False         True        False          False            False
# 4          False        False         True           True            False
#
#    genre_popad  genre_magic  genre_foreign  genre_psychology  genre_prose
# 0        False        False          False             False        False
# 1        False        False          False             False        False
# 2        False        False          False             False         True
# 3        False        False           True             False        False
# 4        False        False          False             False        False

# %% [markdown]
# #### `formats`, `url`

# %%
df1[["formats", "url"]].isna().sum()
# Out:
# formats    0
# url        0
# dtype: int64

# %% [markdown]
# Эти столбцы полезны нам только для создания столбца "является аудиокнигой" для дальнейшего анализа и разделения столбца `lit_pages` на кол-во страниц и продолжительность аудиокниги

# %%
df1["is_audiobook"] = df1["url"].str.contains("/audiobook/")

# %%
df1["duration"] = np.where(df1["is_audiobook"], df1["lit_pages"], None)
df1["lit_pages"] = np.where(df1["is_audiobook"], None, df1["lit_pages"])

# %%
df1 = df1.drop(columns=["formats", "url"])

# %% [markdown]
# #### `categories`, `gb_publisher`, `description`

# %%
df1[["categories", "gb_publisher", "description"]].isna().sum()
# Out:
# categories      2684
# gb_publisher    3023
# description     2841
# dtype: int64

# %% [markdown]
# Пропусков много, так как эти поля были взяты из апи гугл книг, а не все книги удалось там найти

# %% [markdown]
# В столбце `categories` указана везде одна основная "категория" книги. Кодировка этого столбца через OHE будет излишней на этапе EDA, поэтому просто приведем её к более удобному строковому формату

# %%
df1["categories"] = df1["categories"].str.lower().str[2:-2]

# %% [markdown]
# #### `print_type`, `gb_pages`, `language`

# %%
df1[["print_type", "gb_pages", "language"]].isna().sum()
# Out:
# print_type    8868
# gb_pages      2544
# language      2516
# dtype: int64

# %%
pd.DataFrame(df1["language"].value_counts())
# Out:
#           count
# language
# ru         6340
# en            9
# ja            1
# fr            1
# es            1

# %% [markdown]
# `print_type` - пустой, удаляем
# `gb_pages` - нет надобности, так как в lit_pages нет пропусков
# `language` - 99.8% имеют значение "ru", а других категорий слишком мало, этот столбец не подходит для анализа

# %%
df1 = df1.drop(columns=["print_type", "gb_pages", "language"])
df1.shape
# Out:
# (8868, 34)

# %% [markdown]
# #### `country`, `saleability`, `is_ebook`, `retail_price`, `currency_code`, `viewability`, `public_domain`

# %%
df1[["country", "saleability", "is_ebook", "retail_price", "currency_code", "viewability", "public_domain"]].isna().sum()
# Out:
# country          2516
# saleability      2516
# is_ebook         2516
# retail_price     3851
# currency_code    3851
# viewability      2516
# public_domain    2516
# dtype: int64

# %% [markdown]
# 2516 пропусков это кол-во книг, которые не были найдены в api гугл книг. У некоторых так же отдельно не были найдены только цены

# %% [markdown]
# `print_type` - пустой, удаляем
# `gb_pages` - нет надобности, так как в lit_pages нет пропусков
# `language` - 99.8% имеют значение "ru", а других категорий слишком мало, этот столбец не подходит для анализа

# %%
pd.DataFrame(df1["country"].value_counts())
# Out:
#          count
# country
# NL        6352

# %% [markdown]
# Все страны - Нидерланды, как же так вышло, когда мы все сидели с российского ip адреса, как же так...

# %%
df1 = df1.drop(columns=["country"])

# %%
pd.DataFrame(df1["saleability"].value_counts()) # - оставляем
# Out:
#               count
# saleability
# FOR_SALE       5017
# NOT_FOR_SALE   1332
# FREE              3

# %% [markdown]
# Столбцы с Nan можно заполнить "NOT_FOR_SALE" книга не была найдена в api гугл книг, значит, в гугл книгах она не продается

# %%
df1["saleability"] = df1["saleability"].fillna("NOT_FOR_SALE")

# %%
pd.DataFrame(df1["is_ebook"].value_counts()) # - оставляем
# Out:
#           count
# is_ebook
# True       5020
# False      1332

# %%
pd.DataFrame(df1["currency_code"].value_counts())
# Out:
#                count
# currency_code
# EUR             5017

# %% [markdown]
# Нужно перевести все `retail_price` в рубли. Для этого возьмем курс евро на момент создания датасета - 91.56

# %%
df1["retail_price"] = df1["retail_price"]*91.56

# %%
df1 = df1.drop(columns=["currency_code"])

# %%
pd.DataFrame(df1["viewability"].value_counts()) # - оставляем
# Out:
#              count
# viewability
# PARTIAL       5766
# NO_PAGES       583
# ALL_PAGES        3

# %%
df1["viewability"] = df1["viewability"].fillna("NO_PAGES")

# %%
pd.DataFrame(df1["public_domain"].value_counts())
# Out:
#                count
# public_domain
# False           6349
# True               3

# %% [markdown]
# Слишком большой перевес одного класса - не подойдет для анализа

# %%
df1 = df1.drop(columns=["public_domain"])

# %% [markdown]
# #### `epub_avaliable`, `pdf_avaliable`

# %%
df1[["epub_avaliable", "pdf_avaliable"]].isna().sum()
# Out:
# epub_avaliable    2516
# pdf_avaliable     2516
# dtype: int64

# %% [markdown]
# Показывают в каком формате книга доступна для прочтения, если у неё есть бесплатные страницы для прочтения. Если книга не была найдена, то оба формата недоступны. Можно заполнить Nan через False

# %%
df1["epub_avaliable"] = df1["epub_avaliable"].fillna(False)
df1["pdf_avaliable"] = df1["pdf_avaliable"].fillna(False)
# Out:
# /var/folders/4z/3fr35yyn2w34chm4bp6ywypc0000gn/T/ipykernel_62228/54690582.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1["epub_avaliable"] = df1["epub_avaliable"].fillna(False)
# /var/folders/4z/3fr35yyn2w34chm4bp6ywypc0000gn/T/ipykernel_62228/54690582.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1["pdf_avaliable"] = df1["pdf_avaliable"].fillna(False)

# %%
df1
# Out:
#                                                   title  \
# 0                             По осколкам твоего сердца
# 1                             Твое сердце будет разбито
# 2                                   Фейерверк на ладони
# 3                                    Проект «Аве Мария»
# 4                             По осколкам твоего сердца
# ...                                                 ...
# 8863                               Загадка тихого озера
# 8864  Анатомия центральной нервной системы 2-е изд.,...
# 8865                     Аграрная история Древнего мира
# 8866  Организационная социальная психология 2-е изд....
# 8867              Другая сторона. Том 16. Большая Гонка
#
#                               author  has_isbn  rating  reviews_count  price  \
# 0                         Анна Джейн     False     4.9         3530.0  229.0
# 1                         Анна Джейн     False     4.8         7228.0  199.0
# 2                     Ольга Назарова     False     4.9          139.0  189.0
# 3                         Энди Вейер     False     4.8         2117.0  529.0
# 4                         Анна Джейн     False     4.8          921.0  749.0
# ...                              ...       ...     ...            ...    ...
# 8863                  Дарья Калинина     False     5.0            1.0  379.0
# 8864    Вячеслав Альбертович Дубынин      True     5.0            1.0    1.0
# 8865  Дмитрий Моисеевич Петрушевский      True     0.0            NaN    1.0
# 8866      Людмила Георгиевна Почебут      True     3.0            3.0    1.0
# 8867                 Родион Кораблев     False     5.0          141.0  399.0
#
#      publication_year lit_pages  age_restriction         lit_publisher  \
# 0              2025.0     500.0               16                 Автор
# 1              2022.0     510.0               16                 Автор
# 2              2026.0     430.0               16                 Автор
# 3              2021.0      None               16             Аудио-ЛАУ
# 4              2022.0      None               16   Издательство CLEVER
# ...               ...       ...              ...                   ...
# 8863           2026.0      None               16                 Эксмо
# 8864           2023.0     343.0                0                 ЮРАЙТ
# 8865           2021.0     320.0                0                 ЮРАЙТ
# 8866           2017.0     303.0                0                 ЮРАЙТ
# 8867           2024.0      None               16                ЛитРес
#
#                categories     gb_publisher  \
# 0                 fiction  ЛитРес, SelfPub
# 1     young adult fiction  ЛитРес, SelfPub
# 2                     NaN              NaN
# 3                     NaN              Ast
# 4                 fiction  ЛитРес, SelfPub
# ...                   ...              ...
# 8863              fiction           ЛитРес
# 8864            education           ЛитРес
# 8865              history           Litres
# 8866           psychology           ЛитРес
# 8867                  NaN              NaN
#
#                                             description   saleability  \
# 0     Он был моей единственной любовью. Плохой парен...      FOR_SALE
# 1     Я вижу его каждый день в окне дома напротив. О...      FOR_SALE
# 2                                                   NaN  NOT_FOR_SALE
# 3                                                   NaN  NOT_FOR_SALE
# 4     Он был моей единственной любовью. Плохой парен...      FOR_SALE
# ...                                                 ...           ...
# 8863  Новая загадка для трех неутомимых сыщиц!Безмят...      FOR_SALE
# 8864  В курсе рассматриваются строение нервной ткани...      FOR_SALE
# 8865  Классический труд экономической мысли, книга н...      FOR_SALE
# 8866  В учебном пособии описаны сущность, специфика ...      FOR_SALE
# 8867                                                NaN  NOT_FOR_SALE
#
#      is_ebook  retail_price viewability  epub_avaliable  pdf_avaliable  \
# 0        True      247.2120     PARTIAL            True           True
# 1        True      203.2632     PARTIAL            True           True
# 2         NaN           NaN    NO_PAGES           False          False
# 3       False           NaN    NO_PAGES           False          False
# 4        True      247.2120     PARTIAL            True           True
# ...       ...           ...         ...             ...            ...
# 8863     True      358.9152     PARTIAL            True           True
# 8864     True     1718.5812     PARTIAL           False           True
# 8865     True     1044.6996     PARTIAL           False           True
# 8866     True     1288.2492     PARTIAL           False           True
# 8867      NaN           NaN    NO_PAGES           False          False
#
#       genre_fantasy  genre_scifi  genre_novel  genre_romance  genre_detective  \
# 0             False        False         True           True            False
# 1             False        False         True           True            False
# 2             False        False        False          False            False
# 3             False         True        False          False            False
# 4             False        False         True           True            False
# ...             ...          ...          ...            ...              ...
# 8863          False        False        False          False             True
# 8864          False        False        False          False            False
# 8865          False        False        False          False            False
# 8866          False        False        False          False            False
# 8867          False         True        False          False            False
#
#       genre_popad  genre_magic  genre_foreign  genre_psychology  genre_prose  \
# 0           False        False          False             False        False
# 1           False        False          False             False        False
# 2           False        False          False             False         True
# 3           False        False           True             False        False
# 4           False        False          False             False        False
# ...           ...          ...            ...               ...          ...
# 8863        False        False          False             False         True
# 8864        False        False          False             False        False
# 8865        False        False          False             False        False
# 8866        False        False          False              True        False
# 8867         True        False          False             False        False
#
#       is_audiobook duration
# 0            False     None
# 1            False     None
# 2            False     None
# 3             True     21.0
# 4             True     14.0
# ...            ...      ...
# 8863          True      7.0
# 8864         False     None
# 8865         False     None
# 8866         False     None
# 8867          True      8.0
#
# [8868 rows x 31 columns]

# %% [markdown]
# ## Анализ признаков

# %%
import seaborn as sns

sns.barplot(df1.value_counts('has_isbn'))
# Out:
# <Axes: xlabel='has_isbn', ylabel='count'>

# %%
sns.histplot(df1['rating'], binwidth=0.2)
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
df1['rating'].describe()
# Out:
# count    8868.000000
# mean        4.655097
# std         0.669485
# min         0.000000
# 25%         4.600000
# 50%         4.800000
# 75%         4.900000
# max         5.000000
# Name: rating, dtype: float64

# %%
sns.histplot(df1[df1['rating'] >= 4]['rating'], binwidth=0.03)
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
df1['reviews_count'].isna().sum()
# Out:
# np.int64(153)

# %%
df1['reviews_count'].describe()
# Out:
# count    8715.000000
# mean      665.452553
# std      1165.052877
# min         1.000000
# 25%        52.000000
# 50%       224.000000
# 75%       760.500000
# max      9917.000000
# Name: reviews_count, dtype: float64

# %%
df1['reviews_count'].isna().sum()
# Out:
# np.int64(153)

# %%
sns.boxplot(df1['reviews_count'])
# Out:
# <Axes: ylabel='reviews_count'>

# %% [markdown]
# Видно, что количества оценок больше 2000 являются выбросами. Такой график неудобно анализировать. Построим график без них

# %%
sns.histplot(df1[df1['reviews_count'] <= 2000]['reviews_count'])
# Out:
# <Axes: xlabel='reviews_count', ylabel='Count'>

# %% [markdown]
# `price`

# %%
df1['price'].describe()
# Out:
# count    8707.000000
# mean      369.009971
# std       183.858590
# min         1.000000
# 25%       219.000000
# 50%       349.000000
# 75%       499.000000
# max       999.000000
# Name: price, dtype: float64

# %%
import matplotlib.pyplot as plt

sns.histplot(df1['price'], kde=True)
plt.title("Цена книги")
# Out:
# Text(0.5, 1.0, 'Цена книги')

# %% [markdown]
# Проверим, распределены ли цены по нормальному закону
#
# Н0: цены распределены по нормальному закону
#
# Н1: цены не распределены по нормальному закону

# %%
from scipy.stats import shapiro

stat, p = shapiro(df1[~df1['price'].isna()]['price'])
p
# Out:
# /Users/alinadriagina/miniconda3/lib/python3.12/site-packages/scipy/stats/_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 8707.
#   res = hypotest_fun_out(*samples, **kwds)
# np.float64(4.2629076252568213e-41)

# %% [markdown]
# p < 0.05, поэтому отклоняем нулевую гипотезу, цены не распределены по нормальному закону

# %% [markdown]
# `publication_year`

# %%
df1['publication_year'].astype(float).describe()
# Out:
# count    8268.000000
# mean     2016.667755
# std        24.000676
# min      1170.000000
# 25%      2018.000000
# 50%      2024.000000
# 75%      2025.000000
# max      2026.000000
# Name: publication_year, dtype: float64

# %%
sns.histplot(df1[df1['publication_year'] >= 2000]['publication_year'])
plt.title("Дата публикации книги")
# Out:
# Text(0.5, 1.0, 'Дата публикации книги')

# %% [markdown]
# Самым частым является 2025 год. Это связано с тем, что за 2026 год получена еще не вся информация, так как год еще не заончился

# %% [markdown]
# `age_restriction`

# %%
sns.barplot(df1['age_restriction'].value_counts())
plt.title("Возрастные ограничения книг")
# Out:
# Text(0.5, 1.0, 'Возрастные ограничения книг')

# %% [markdown]
# Большинство книг имеют возрастное ограничение 16+, на втором месте по популярности находятся книги с возрастным ограничением 18+

# %% [markdown]
# `is_audiobook`

# %%
sns.barplot(df1.value_counts('is_audiobook'))
plt.title("Является ли книга аудиокнигой")
# Out:
# Text(0.5, 1.0, 'Является ли книга аудиокнигой')

# %% [markdown]
# `lit_pages`

# %%
df1['lit_pages'].astype(float).describe()
# Out:
# count    5594.000000
# mean      353.400608
# std       241.704224
# min         5.000000
# 25%       230.000000
# 50%       296.000000
# 75%       401.000000
# max      3388.000000
# Name: lit_pages, dtype: float64

# %% [markdown]
# Большинство книг имеют количество меньше 500, поэтому для удобства ограничим оси на графике этим диапазоном

# %%
sns.histplot(df1[df1['lit_pages'] < 500]['lit_pages'])
plt.title("Количество страниц")
# Out:
# Text(0.5, 1.0, 'Количество страниц')

# %% [markdown]
# `duration`

# %%
df1['duration'].astype(float).describe()
# Out:
# count    3274.000000
# mean       11.176848
# std         9.956161
# min         1.000000
# 25%         7.000000
# 50%         9.000000
# 75%        12.000000
# max       291.000000
# Name: duration, dtype: float64

# %% [markdown]
# Длительности аудиокниг редко превышают 12 часов, поэтому для удобства ограничим ось на графике

# %%
sns.histplot(df1[df1['duration'] < 40]['duration'])
plt.title("Длительность аудиокниги")
# Out:
# Text(0.5, 1.0, 'Длительность аудиокниги')

# %% [markdown]
# `retail_price`

# %%
df1['retail_price'].describe()
# Out:
# count    5017.000000
# mean      410.610374
# std       359.322877
# min         2.746800
# 25%       247.212000
# 50%       279.258000
# 75%       477.943200
# max      8385.980400
# Name: retail_price, dtype: float64

# %%
sns.histplot(df1[df1['retail_price'] < 1000]['retail_price'])
plt.title("Стоимость книги в google books")
# Out:
# Text(0.5, 1.0, 'Стоимость книги в google books')

# %%
sns.barplot(df1.value_counts('viewability'))
plt.title("Доступность книги на google books")
# Out:
# Text(0.5, 1.0, 'Доступность книги на google books')

# %% [markdown]
# `epub_avaliable`

# %%
sns.barplot(df1.value_counts('epub_avaliable'))
plt.title("Доступность epup")
# Out:
# Text(0.5, 1.0, 'Доступность epup')

# %%
sns.barplot(df1.value_counts('pdf_avaliable'))
plt.title("Доступность pdf")
# Out:
# Text(0.5, 1.0, 'Доступность pdf')

# %%
binary_cols = ['has_isbn', 'is_ebook', 'epub_avaliable', 'pdf_avaliable', 
               'genre_fantasy', 'genre_scifi', 'genre_novel', 'genre_romance',
               'genre_detective', 'genre_popad', 'genre_magic', 'genre_foreign',
               'genre_psychology', 'genre_prose', 'is_audiobook']

numeric_cols = ['rating', 'reviews_count', 'price', 'publication_year', 'age_restriction', 'lit_pages', 'retail_price', 'duration']

# %%
corr_cols = [col for col in binary_cols + numeric_cols]
corr_matrix = df1[corr_cols].corr(method='spearman')

plt.figure(figsize=(16, 10))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Матрица корреляций')
plt.show()

# %%
top_corr = corr_matrix.unstack().reset_index()
top_corr.columns = ['feature_1', 'feature_2', 'corr']

top_corr = top_corr[top_corr['feature_1'] != top_corr['feature_2']]

top_corr['abs_corr'] = top_corr['corr'].abs()

top_corr = top_corr.sort_values('abs_corr', ascending=False)

print(top_corr.head(16))
# Out:
#             feature_1         feature_2      corr  abs_corr
# 71      pdf_avaliable    epub_avaliable  0.950696  0.950696
# 49     epub_avaliable     pdf_avaliable  0.950696  0.950696
# 167     genre_romance       genre_novel  0.717753  0.717753
# 145       genre_novel     genre_romance  0.717753  0.717753
# 500      retail_price             price  0.685805  0.685805
# 412             price      retail_price  0.685805  0.685805
# 234       genre_magic     genre_fantasy  0.607700  0.607700
# 102     genre_fantasy       genre_magic  0.607700  0.607700
# 70      pdf_avaliable          is_ebook  0.595977  0.595977
# 26           is_ebook     pdf_avaliable  0.595977  0.595977
# 322      is_audiobook          has_isbn -0.546182  0.546182
# 14           has_isbn      is_audiobook -0.546182  0.546182
# 47     epub_avaliable          is_ebook  0.545294  0.545294
# 25           is_ebook    epub_avaliable  0.545294  0.545294
# 386     reviews_count  publication_year -0.507809  0.507809
# 430  publication_year     reviews_count -0.507809  0.507809

# %%
plot_cols = ['rating', 'reviews_count', 'price', 'publication_year', 'age_restriction', 'lit_pages', 'retail_price', 'duration']

sample_for_plot = df1[plot_cols]

sns.pairplot(sample_for_plot)
plt.show()

# %%
temp = df1[['price', 'retail_price']].dropna()
sns.scatterplot(data=temp, x='price', y='retail_price', alpha=0.5)
sns.regplot(data=temp, x='price', y='retail_price', scatter=False, color='red')
plt.title('price и retail_price')
plt.show()

# %%
temp = df1[['genre_foreign', 'price']].dropna()
sns.boxplot(data=temp, x='genre_foreign', y='price')
plt.title('price по genre_foreign')
plt.show()

# %%
temp = df1[['genre_foreign', 'rating']].dropna()

q2 = temp['rating'].quantile(0.02)
q98 = temp['rating'].quantile(0.98)

temp = temp[(temp['rating'] >= q2) & (temp['rating'] <= q98)]


sns.boxplot(data=temp, x='genre_foreign', y='rating')
plt.title('rating по genre_foreign')
plt.show()

# %%
temp = df1[['genre_romance', 'price']].dropna()
sns.boxplot(data=temp, x='genre_romance', y='price')
plt.title('price по genre_romance')
plt.show()

# %%
sns.barplot(data=df1, x='genre_fantasy', y='genre_magic')

plt.title('Доля magic внутри fantasy')
plt.xlabel('genre_fantasy')
plt.ylabel('Доля')
plt.ylim(0, 1)
plt.show()

# %%
temp = df1[['genre_fantasy', 'price']].dropna()

sns.boxplot(data=temp, x='genre_fantasy', y='price')
plt.title('Цена по fantasy')
plt.show()

# %%
temp = df1[['price', 'rating']].dropna()

sns.scatterplot(data=temp, x='price', y='rating', alpha=0.5)
sns.regplot(data=temp, x='price', y='rating', scatter=False, color='red')
plt.title('price и rating')
plt.tight_layout()
plt.show()

# %%
temp = df1[['has_isbn', 'price']].dropna()

plt.figure()
sns.boxplot(data=temp, x='has_isbn', y='price')
plt.title(f'price по признаку isbn')
plt.show()

# %%
temp = df1[['age_restriction', 'price']].dropna()
plt.figure(figsize=(10, 6))
sns.boxplot(data=temp, x='age_restriction', y='price')
plt.title('Цена по возрастному ограничению')
plt.xlabel('Возрастное ограничение')
plt.ylabel('Цена')
plt.tight_layout()
plt.show()

# %%
genres = ['genre_fantasy', 'genre_scifi', 'genre_novel', 'genre_romance', 'genre_detective', 
          'genre_popad', 'genre_magic', 'genre_foreign', 'genre_psychology', 'genre_prose']

mean_ratings = []
for genre in genres:
    mean_rating = df1[df1[genre] == 1]['rating'].mean()
    mean_ratings.append(mean_rating)

plt.figure(figsize=(10, 5))
plt.bar(genres, mean_ratings)
plt.title('Средний рейтинг по жанрам')
plt.xlabel('Жанр')
plt.ylabel('Средний рейтинг')
plt.xticks(rotation=45)
plt.show()

# %%
genres = ['genre_fantasy', 'genre_scifi', 'genre_novel', 'genre_romance', 'genre_detective', 
          'genre_popad', 'genre_magic', 'genre_foreign', 'genre_psychology', 'genre_prose']


mean_price = []
for genre in genres:
    mean_pr = df1[df1[genre] == 1]['price'].mean()
    mean_price.append(mean_pr)

plt.figure(figsize=(10, 5))
plt.bar(genres, mean_price)
plt.title('Средняя цена по жанрам')
plt.xlabel('Жанр')
plt.ylabel('Средний цена')
plt.xticks(rotation=45)
plt.show()

# %%
genres = ['genre_fantasy', 'genre_scifi', 'genre_novel', 'genre_romance', 'genre_detective', 
          'genre_popad', 'genre_magic', 'genre_foreign', 'genre_psychology', 'genre_prose']

result = []
for genre in genres:
    mean_reviews = df1[df1[genre] == 1]['reviews_count'].mean()
    result.append([genre, mean_reviews])

temp = pd.DataFrame(result, columns=['genre', 'mean_reviews_count'])

plt.figure(figsize=(10, 5))
sns.barplot(data=temp, x='genre', y='mean_reviews_count')
plt.title('Среднее число отзывов по жанрам')
plt.xlabel('Жанр')
plt.ylabel('Среднее колво отзывов')
plt.xticks(rotation=45)
plt.show()

# %%
temp = df1['publication_year'].value_counts().sort_index()
temp = temp[temp.index >= 2000]

plt.figure(figsize=(12, 5))
plt.plot(temp.index, temp.values)
plt.title('Количество книг по годам')
plt.xlabel('Год публикации')
plt.ylabel('Количество книг')
plt.grid(alpha = 0.2)
plt.show()

# %%
temp = df1.groupby('publication_year')['reviews_count'].mean()
temp = temp[temp.index >= 2000]

plt.figure(figsize=(12, 5))
plt.plot(temp.index, temp.values)
plt.title('Среднее количество оценок на книгу по годам публикации')
plt.xlabel('Год публикации')
plt.ylabel('Среднее количество оценок на книгу')
plt.grid(alpha = 0.2)
plt.show()

# %%
temp = df1[['publication_year', 'is_ebook']].dropna()

temp = temp.groupby('publication_year')['is_ebook'].agg(['count', 'mean'])
temp = temp[temp['count'] >= 10].reset_index()
temp = temp[temp['publication_year'] >= 2000]

plt.figure(figsize=(12, 5))
sns.lineplot(data=temp, x='publication_year', y='mean')
plt.title('Доля ebook по годам')
plt.xlabel('Год публикации')
plt.ylabel('Доля ebook')
plt.grid(alpha = 0.2)
plt.show()

# %%
temp = df1[['is_ebook', 'publication_year']].dropna()

q5 = temp['publication_year'].quantile(0.05)
q95 = temp['publication_year'].quantile(0.95)

temp = temp[(temp['publication_year'] >= q5) & (temp['publication_year'] <= q95)]

sns.boxplot(data=temp, x='is_ebook', y='publication_year')
plt.ylim(1975, 2030)
plt.title('Типа книг по годам выпуска')
plt.grid(alpha = 0.2)
plt.show()

# %% [markdown]
# ## New York Times

# %% [markdown]
# Рассмотрим датасет собранный из бестселлеров New York Times, обогащенный информацией из api гугл книг, hardcover api и openlibrary api

# %%
df2 = pd.read_csv("final_nyt_x_google_x_hardcover.csv")
df2.head()
# Out:
#    Unnamed: 0.2       id_book               categories publisher_google  \
# 0             0           NaN                      NaN              NaN
# 1             1           NaN                      NaN              NaN
# 2             2  j44fEQAAQBAJ              ['Fiction']     Random House
# 3             3  hwm8DwAAQBAJ     ['Juvenile Fiction']    HarperCollins
# 4             4  LehCEAAAQBAJ  ['Body, Mind & Spirit']    HarperCollins
#
#                                   description_google  print_type  page_count  \
# 0                                                NaN         NaN         NaN
# 1                                                NaN         NaN         NaN
# 2  The dazzling new love story and Reese Withersp...         NaN       363.0
# 3  INSPIRED BY A TRUE STORY FROM THE CHILDHOOD OF...         NaN        37.0
# 4  AN INSTANT NEW YORK TIMES BESTSELLER "The perf...         NaN       271.0
#
#   language country saleability is_ebook  retail_price currency_code  \
# 0      NaN     NaN         NaN      NaN           NaN           NaN
# 1      NaN     NaN         NaN      NaN           NaN           NaN
# 2       en      RU    FOR_SALE     True       2138.54           RUB
# 3       en      RU    FOR_SALE     True       1032.34           RUB
# 4       en      RU    FOR_SALE     True       1521.74           RUB
#
#   viewability public_domain epub_avaliable pdf_avaliable  Unnamed: 0.1  \
# 0         NaN           NaN            NaN           NaN          9791
# 1         NaN           NaN            NaN           NaN          9453
# 2     PARTIAL         False           True         False            62
# 3     PARTIAL         False           True          True          1981
# 4     PARTIAL         False           True         False          2290
#
#    Unnamed: 0 age_group                                 amazon_product_url  \
# 0          38       NaN  https://www.amazon.com/dp/125031397X?tag=thene...
# 1         491       NaN  https://www.amazon.com/dp/1464223335?tag=thene...
# 2          62       NaN  https://www.amazon.com/dp/059344129X?tag=thene...
# 3        1366       NaN  https://www.amazon.com/dp/0062937405?tag=thene...
# 4        1675       NaN  https://www.amazon.com/dp/0063221942?tag=thene...
#
#    article_chapter_link  asterisk         author  \
# 0                   NaN         0   Aiden Thomas
# 1                   NaN         0      Ana Huang
# 2                   NaN         0    Emily Henry
# 3                   NaN         0   Meena Harris
# 4                   NaN         0  Jenna Kutcher
#
#                                           book_image  book_image_height  \
# 0  https://static01.nyt.com/bestsellers/images/97...                500
# 1  https://static01.nyt.com/bestsellers/images/97...                500
# 2  https://static01.nyt.com/bestsellers/images/97...                500
# 3  https://static01.nyt.com/bestsellers/images/97...                500
# 4  https://static01.nyt.com/bestsellers/images/97...                500
#
#    book_image_width book_review_link  \
# 0               323              NaN
# 1               324              NaN
# 2               331              NaN
# 3               389              NaN
# 4               331              NaN
#
#                                           book_uri  \
# 0  nyt://book/5415bdba-f840-505b-951b-f7aab2498c65
# 1  nyt://book/fdfee028-8ada-5b4f-b380-4f0ab8aee897
# 2  nyt://book/cec5ff36-29d1-58cc-a522-9611a0ad9fe1
# 3  nyt://book/d1fd48e8-5183-5fb2-b9be-6fc6a179f31a
# 4  nyt://book/05beddb6-4682-5cb0-8319-f37f3646e13c
#
#                                          contributor  \
# 0                                    by Aiden Thomas
# 1                                       by Ana Huang
# 2                                     by Emily Henry
# 3  by Meena Harris. Illustrated by Ana Ramírez Go...
# 4                                   by Jenna Kutcher
#
#                       contributor_note              created_date  dagger  \
# 0                                  NaN  2026-03-06T06:19:00.358Z       0
# 1                                  NaN  2026-03-05T17:47:52.965Z       0
# 2                                  NaN  2026-03-18T00:52:24.385Z       0
# 3  Illustrated by Ana Ramírez González  2026-03-06T06:03:32.289Z       0
# 4                                  NaN  2026-03-06T05:18:30.124Z       1
#
#                                          description first_chapter_link  \
# 0  Wendy assists Peter Pan to find missing childr...                NaN
# 1  The second book in the Gods of the Game series...                NaN
# 2  A writer looking for her big break competes ag...                NaN
# 3  Two sisters turn their empty apartment courtya...                NaN
# 4                                                NaN                NaN
#
#    price  primary_isbn10 primary_isbn13      publisher  rank  rank_last_week  \
# 0    0.0             NaN  9781250313973    Swoon Reads     4               0
# 1    0.0             NaN  9781464223334          Bloom     1               0
# 2    0.0             NaN  9798217063987  Penguin Audio     1               0
# 3    0.0             NaN  9780062937407  Balzer + Bray     5               0
# 4    0.0             NaN  9780063221949     Dey Street     7               0
#
#   sunday_review_link                       title              updated_date  \
# 0                NaN     LOST IN THE NEVER WOODS  2026-03-06T06:19:00.358Z
# 1                NaN                THE DEFENDER  2026-03-05T17:47:52.965Z
# 2                NaN    GREAT BIG BEAUTIFUL LIFE  2026-03-18T00:52:24.385Z
# 3                NaN  KAMALA AND MAYA'S BIG IDEA  2026-03-06T06:03:32.289Z
# 4                NaN        HOW ARE YOU, REALLY?  2026-03-06T05:18:30.124Z
#
#    weeks_on_list                                        isbns  \
# 0              1  [{'isbn10': '', 'isbn13': '9781250313973'}]
# 1              1  [{'isbn10': '', 'isbn13': '9781464223334'}]
# 2              0  [{'isbn10': '', 'isbn13': '9798217063987'}]
# 3              1  [{'isbn10': '', 'isbn13': '9780062937407'}]
# 4              0  [{'isbn10': '', 'isbn13': '9780063221949'}]
#
#                                            buy_links  avg_rating  \
# 0  [{'name': 'Amazon', 'url': 'https://www.amazon...         1.0
# 1  [{'name': 'Amazon', 'url': 'https://www.amazon...         1.0
# 2  [{'name': 'Amazon', 'url': 'https://www.amazon...         1.0
# 3  [{'name': 'Amazon', 'url': 'https://www.amazon...         1.0
# 4  [{'name': 'Amazon', 'url': 'https://www.amazon...         1.0
#
#    rating_count          title_open_library  \
# 0           1.0     Lost in the Never Woods
# 1           1.0                The Defender
# 2           1.0    Great Big Beautiful Life
# 3           1.0  Kamala and Maya’s Big Idea
# 4           1.0        How Are You, Really?
#
#                         author_open_library  \
# 0             ['Aiden Thomas', 'Avi Roque']
# 1                             ['Ana Huang']
# 2                           ['Emily Henry']
# 3  ['Meena Harris', 'Ana Ramírez González']
# 4                         ['Jenna Kutcher']
#
#                                      hardcover_title  \
# 0                            Lost in the Never Woods
# 1                                       The Defender
# 2                           Great Big Beautiful Life
# 3                         Kamala and Maya’s Big Idea
# 4  How Are You, Really? Living Your Truth One Ans...
#
#                   hardcover_author  hardcover_rating  hardcover_ratings_count  \
# 0     ['Aiden Thomas' 'Avi Roque']          3.666667                     39.0
# 1                    ['Ana Huang']          3.954545                     11.0
# 2                  ['Emily Henry']          3.845528                    246.0
# 3  ['Meena Harris' 'Ana González']          4.666667                      3.0
# 4                ['Jenna Kutcher']          2.333333                      3.0
#
#    release_year  users_count  \
# 0        2000.0        249.0
# 1        2025.0         31.0
# 2        2025.0        704.0
# 3        2020.0          6.0
# 4        2022.0         12.0
#
#                                               genres
# 0  ['Fantasy' 'Young Adult' 'LGBTQ' 'Young Adult ...
# 1                                        ['Fiction']
# 2  ['Fiction' 'Romance' 'Contemporary Romance' 'r...
# 3                                                 []
# 4                                                 []

# %%
df2.shape
# Out:
# (3866, 58)

# %% [markdown]
# Удалим заведомо ненужные для анализа столбцы

# %%
df2.head(5)
# Out:
#    Unnamed: 0.2       id_book               categories publisher_google  \
# 0             0           NaN                      NaN              NaN
# 1             1           NaN                      NaN              NaN
# 2             2  j44fEQAAQBAJ              ['Fiction']     Random House
# 3             3  hwm8DwAAQBAJ     ['Juvenile Fiction']    HarperCollins
# 4             4  LehCEAAAQBAJ  ['Body, Mind & Spirit']    HarperCollins
#
#                                   description_google  print_type  page_count  \
# 0                                                NaN         NaN         NaN
# 1                                                NaN         NaN         NaN
# 2  The dazzling new love story and Reese Withersp...         NaN       363.0
# 3  INSPIRED BY A TRUE STORY FROM THE CHILDHOOD OF...         NaN        37.0
# 4  AN INSTANT NEW YORK TIMES BESTSELLER "The perf...         NaN       271.0
#
#   language country saleability is_ebook  retail_price currency_code  \
# 0      NaN     NaN         NaN      NaN           NaN           NaN
# 1      NaN     NaN         NaN      NaN           NaN           NaN
# 2       en      RU    FOR_SALE     True       2138.54           RUB
# 3       en      RU    FOR_SALE     True       1032.34           RUB
# 4       en      RU    FOR_SALE     True       1521.74           RUB
#
#   viewability public_domain epub_avaliable pdf_avaliable  Unnamed: 0.1  \
# 0         NaN           NaN            NaN           NaN          9791
# 1         NaN           NaN            NaN           NaN          9453
# 2     PARTIAL         False           True         False            62
# 3     PARTIAL         False           True          True          1981
# 4     PARTIAL         False           True         False          2290
#
#    Unnamed: 0 age_group                                 amazon_product_url  \
# 0          38       NaN  https://www.amazon.com/dp/125031397X?tag=thene...
# 1         491       NaN  https://www.amazon.com/dp/1464223335?tag=thene...
# 2          62       NaN  https://www.amazon.com/dp/059344129X?tag=thene...
# 3        1366       NaN  https://www.amazon.com/dp/0062937405?tag=thene...
# 4        1675       NaN  https://www.amazon.com/dp/0063221942?tag=thene...
#
#    article_chapter_link  asterisk         author  \
# 0                   NaN         0   Aiden Thomas
# 1                   NaN         0      Ana Huang
# 2                   NaN         0    Emily Henry
# 3                   NaN         0   Meena Harris
# 4                   NaN         0  Jenna Kutcher
#
#                                           book_image  book_image_height  \
# 0  https://static01.nyt.com/bestsellers/images/97...                500
# 1  https://static01.nyt.com/bestsellers/images/97...                500
# 2  https://static01.nyt.com/bestsellers/images/97...                500
# 3  https://static01.nyt.com/bestsellers/images/97...                500
# 4  https://static01.nyt.com/bestsellers/images/97...                500
#
#    book_image_width book_review_link  \
# 0               323              NaN
# 1               324              NaN
# 2               331              NaN
# 3               389              NaN
# 4               331              NaN
#
#                                           book_uri  \
# 0  nyt://book/5415bdba-f840-505b-951b-f7aab2498c65
# 1  nyt://book/fdfee028-8ada-5b4f-b380-4f0ab8aee897
# 2  nyt://book/cec5ff36-29d1-58cc-a522-9611a0ad9fe1
# 3  nyt://book/d1fd48e8-5183-5fb2-b9be-6fc6a179f31a
# 4  nyt://book/05beddb6-4682-5cb0-8319-f37f3646e13c
#
#                                          contributor  \
# 0                                    by Aiden Thomas
# 1                                       by Ana Huang
# 2                                     by Emily Henry
# 3  by Meena Harris. Illustrated by Ana Ramírez Go...
# 4                                   by Jenna Kutcher
#
#                       contributor_note              created_date  dagger  \
# 0                                  NaN  2026-03-06T06:19:00.358Z       0
# 1                                  NaN  2026-03-05T17:47:52.965Z       0
# 2                                  NaN  2026-03-18T00:52:24.385Z       0
# 3  Illustrated by Ana Ramírez González  2026-03-06T06:03:32.289Z       0
# 4                                  NaN  2026-03-06T05:18:30.124Z       1
#
#                                          description first_chapter_link  \
# 0  Wendy assists Peter Pan to find missing childr...                NaN
# 1  The second book in the Gods of the Game series...                NaN
# 2  A writer looking for her big break competes ag...                NaN
# 3  Two sisters turn their empty apartment courtya...                NaN
# 4                                                NaN                NaN
#
#    price  primary_isbn10 primary_isbn13      publisher  rank  rank_last_week  \
# 0    0.0             NaN  9781250313973    Swoon Reads     4               0
# 1    0.0             NaN  9781464223334          Bloom     1               0
# 2    0.0             NaN  9798217063987  Penguin Audio     1               0
# 3    0.0             NaN  9780062937407  Balzer + Bray     5               0
# 4    0.0             NaN  9780063221949     Dey Street     7               0
#
#   sunday_review_link                       title              updated_date  \
# 0                NaN     LOST IN THE NEVER WOODS  2026-03-06T06:19:00.358Z
# 1                NaN                THE DEFENDER  2026-03-05T17:47:52.965Z
# 2                NaN    GREAT BIG BEAUTIFUL LIFE  2026-03-18T00:52:24.385Z
# 3                NaN  KAMALA AND MAYA'S BIG IDEA  2026-03-06T06:03:32.289Z
# 4                NaN        HOW ARE YOU, REALLY?  2026-03-06T05:18:30.124Z
#
#    weeks_on_list                                        isbns  \
# 0              1  [{'isbn10': '', 'isbn13': '9781250313973'}]
# 1              1  [{'isbn10': '', 'isbn13': '9781464223334'}]
# 2              0  [{'isbn10': '', 'isbn13': '9798217063987'}]
# 3              1  [{'isbn10': '', 'isbn13': '9780062937407'}]
# 4              0  [{'isbn10': '', 'isbn13': '9780063221949'}]
#
#                                            buy_links  avg_rating  \
# 0  [{'name': 'Amazon', 'url': 'https://www.amazon...         1.0
# 1  [{'name': 'Amazon', 'url': 'https://www.amazon...         1.0
# 2  [{'name': 'Amazon', 'url': 'https://www.amazon...         1.0
# 3  [{'name': 'Amazon', 'url': 'https://www.amazon...         1.0
# 4  [{'name': 'Amazon', 'url': 'https://www.amazon...         1.0
#
#    rating_count          title_open_library  \
# 0           1.0     Lost in the Never Woods
# 1           1.0                The Defender
# 2           1.0    Great Big Beautiful Life
# 3           1.0  Kamala and Maya’s Big Idea
# 4           1.0        How Are You, Really?
#
#                         author_open_library  \
# 0             ['Aiden Thomas', 'Avi Roque']
# 1                             ['Ana Huang']
# 2                           ['Emily Henry']
# 3  ['Meena Harris', 'Ana Ramírez González']
# 4                         ['Jenna Kutcher']
#
#                                      hardcover_title  \
# 0                            Lost in the Never Woods
# 1                                       The Defender
# 2                           Great Big Beautiful Life
# 3                         Kamala and Maya’s Big Idea
# 4  How Are You, Really? Living Your Truth One Ans...
#
#                   hardcover_author  hardcover_rating  hardcover_ratings_count  \
# 0     ['Aiden Thomas' 'Avi Roque']          3.666667                     39.0
# 1                    ['Ana Huang']          3.954545                     11.0
# 2                  ['Emily Henry']          3.845528                    246.0
# 3  ['Meena Harris' 'Ana González']          4.666667                      3.0
# 4                ['Jenna Kutcher']          2.333333                      3.0
#
#    release_year  users_count  \
# 0        2000.0        249.0
# 1        2025.0         31.0
# 2        2025.0        704.0
# 3        2020.0          6.0
# 4        2022.0         12.0
#
#                                               genres
# 0  ['Fantasy' 'Young Adult' 'LGBTQ' 'Young Adult ...
# 1                                        ['Fiction']
# 2  ['Fiction' 'Romance' 'Contemporary Romance' 'r...
# 3                                                 []
# 4                                                 []

# %%
df2 = df2.drop(columns=["Unnamed: 0.1", "Unnamed: 0", "amazon_product_url", "article_chapter_link", "asterisk", "book_image", "book_image_height",
                        "book_image_width", "book_review_link", "book_uri", "contributor", "contributor_note", "created_date", "first_chapter_link",
                        "primary_isbn10", "primary_isbn13", "sunday_review_link", "updated_date", "isbns", "buy_links", "hardcover_title", "hardcover_author",
                        "title_open_library", "author_open_library", "dagger", "Unnamed: 0.2", "id_book"])

# %%
df2.shape
# Out:
# (3866, 31)

# %% [markdown]
# Переставим столбцы в более логичном для анализа порядке и переименуем некоторые столбцы для избежания разночтений

# %%
df2 = df2[["title", "author", "avg_rating", "rating_count", "hardcover_rating", "hardcover_ratings_count", "users_count", "price", "release_year",
           "age_group", "publisher", "genres", "description", "rank", "rank_last_week", "weeks_on_list", "categories", "publisher_google", "description_google",
           "print_type", "page_count", "language", "country", "saleability", "is_ebook", "retail_price", "currency_code", "viewability", "public_domain",
           "epub_avaliable", "pdf_avaliable"]]

df2 = df2.rename(columns={"avg_rating":"ol_avg_rating", "rating_count":"ol_rating_count"})

# %%
n_duplicates = df2.duplicated(keep=False)
df2[n_duplicates].head(10)
# Out:
# Empty DataFrame
# Columns: [title, author, ol_avg_rating, ol_rating_count, hardcover_rating, hardcover_ratings_count, users_count, price, release_year, age_group, publisher, genres, description, rank, rank_last_week, weeks_on_list, categories, publisher_google, description_google, print_type, page_count, language, country, saleability, is_ebook, retail_price, currency_code, viewability, public_domain, epub_avaliable, pdf_avaliable]
# Index: []

# %% [markdown]
# Дубликатов нет, так как они были зачищены на этапе объединения рейтингов с разных недель, до обогащения через api

# %% [markdown]
# #### `title`, `author`

# %%
df2[["title", "author"]].isna().sum()
# Out:
# title      0
# author    25
# dtype: int64

# %% [markdown]
# Есть 25 пропусков в `author`, посмотрим на эти строки

# %%
df2[df2["author"].isna()]
# Out:
#                                                title author  ol_avg_rating  \
# 3820                     A FIRST TIME FOR EVERYTHING    NaN            NaN
# 3821                             A STUDY IN DROWNING    NaN            NaN
# 3822                      THE SUMMER OF BROKEN RULES    NaN            NaN
# 3823                                   WE WERE LIARS    NaN            NaN
# 3824                             FOLLOWING THE CLUES    NaN            NaN
# 3825                       STUART WOODS' GOLDEN HOUR    NaN            NaN
# 3826                                 HIDDEN PICTURES    NaN            NaN
# 3827                                          SUNSET    NaN            NaN
# 3828                        THE SHERIFF TAKES A WIFE    NaN            NaN
# 3829                                   THE WILD SIDE    NaN            NaN
# 3830                              ON THE ROYLE RANGE    NaN            NaN
# 3831                             ALEX CROSS MUST DIE    NaN            NaN
# 3832                                  RAGE OF EAGLES    NaN            NaN
# 3833                               PASSIONS IN DEATH    NaN            NaN
# 3834                                   CAMINO GHOSTS    NaN            NaN
# 3835                                             JOY    NaN            NaN
# 3836                               DANDADAN, VOL. 13    NaN            NaN
# 3837                       MY HERO ACADEMIA, VOL. 41    NaN            NaN
# 3838                 THE PIGEON HAS TO GO TO SCHOOL!    NaN            NaN
# 3839  ADULT CHILDREN OF EMOTIONALLY IMMATURE PARENTS    NaN            NaN
# 3840                   THE WISHBONE KITCHEN COOKBOOK    NaN            NaN
# 3841                                THE BOOK OF BILL    NaN            NaN
# 3842                             THE HAMPTONS LAWYER    NaN            NaN
# 3843                                       I AM OZZY    NaN            NaN
# 3844                              NOT QUITE DEAD YET    NaN            NaN
#
#       ol_rating_count  hardcover_rating  hardcover_ratings_count  users_count  \
# 3820              NaN               NaN                      NaN          NaN
# 3821              NaN               NaN                      NaN          NaN
# 3822              NaN               NaN                      NaN          NaN
# 3823              NaN               NaN                      NaN          NaN
# 3824              NaN               NaN                      NaN          NaN
# 3825              NaN               NaN                      NaN          NaN
# 3826              NaN               NaN                      NaN          NaN
# 3827              NaN               NaN                      NaN          NaN
# 3828              NaN               NaN                      NaN          NaN
# 3829              NaN               NaN                      NaN          NaN
# 3830              NaN               NaN                      NaN          NaN
# 3831              NaN               NaN                      NaN          NaN
# 3832              NaN               NaN                      NaN          NaN
# 3833              NaN               NaN                      NaN          NaN
# 3834              NaN               NaN                      NaN          NaN
# 3835              NaN               NaN                      NaN          NaN
# 3836              NaN               NaN                      NaN          NaN
# 3837              NaN               NaN                      NaN          NaN
# 3838              NaN               NaN                      NaN          NaN
# 3839              NaN               NaN                      NaN          NaN
# 3840              NaN               NaN                      NaN          NaN
# 3841              NaN               NaN                      NaN          NaN
# 3842              NaN               NaN                      NaN          NaN
# 3843              NaN               NaN                      NaN          NaN
# 3844              NaN               NaN                      NaN          NaN
#
#       price  release_year age_group publisher genres description  rank  \
# 3820    0.0           NaN       NaN       NaN    NaN         NaN     9
# 3821    0.0           NaN       NaN       NaN    NaN         NaN     5
# 3822    0.0           NaN       NaN       NaN    NaN         NaN     2
# 3823    0.0           NaN       NaN       NaN    NaN         NaN     7
# 3824    0.0           NaN       NaN       NaN    NaN         NaN    14
# 3825    0.0           NaN       NaN       NaN    NaN         NaN    11
# 3826    0.0           NaN       NaN       NaN    NaN         NaN    10
# 3827    0.0           NaN       NaN       NaN    NaN         NaN     9
# 3828    0.0           NaN       NaN       NaN    NaN         NaN     8
# 3829    0.0           NaN       NaN       NaN    NaN         NaN     7
# 3830    0.0           NaN       NaN       NaN    NaN         NaN     6
# 3831    0.0           NaN       NaN       NaN    NaN         NaN     5
# 3832    0.0           NaN       NaN       NaN    NaN         NaN     4
# 3833    0.0           NaN       NaN       NaN    NaN         NaN     3
# 3834    0.0           NaN       NaN       NaN    NaN         NaN     2
# 3835    0.0           NaN       NaN       NaN    NaN         NaN     1
# 3836    0.0           NaN       NaN       NaN    NaN         NaN    10
# 3837    0.0           NaN       NaN       NaN    NaN         NaN     7
# 3838    0.0           NaN       NaN       NaN    NaN         NaN     6
# 3839    0.0           NaN       NaN       NaN    NaN         NaN     5
# 3840    0.0           NaN       NaN       NaN    NaN         NaN     4
# 3841    0.0           NaN       NaN       NaN    NaN         NaN     3
# 3842    0.0           NaN       NaN       NaN    NaN         NaN    10
# 3843    0.0           NaN       NaN       NaN    NaN         NaN     7
# 3844    0.0           NaN       NaN       NaN    NaN         NaN     4
#
#       rank_last_week  weeks_on_list           categories publisher_google  \
# 3820               0              1                  NaN              NaN
# 3821               0              1                  NaN              NaN
# 3822               0             11  ['English fiction']              NaN
# 3823               0              0                  NaN              NaN
# 3824               0              1                  NaN              NaN
# 3825               0              1                  NaN              NaN
# 3826               8              2                  NaN              NaN
# 3827               0              1          ['Fiction']   Atlantic Books
# 3828               0              1                  NaN              NaN
# 3829               0              1                  NaN              NaN
# 3830               0              1                  NaN              NaN
# 3831               0              1                  NaN              NaN
# 3832               0              1                  NaN              NaN
# 3833               0              1                  NaN              NaN
# 3834               0              1                  NaN              NaN
# 3835               0              1                  NaN              NaN
# 3836               0              1                  NaN              NaN
# 3837               0              1                  NaN              NaN
# 3838               2             40                  NaN              NaN
# 3839               0              1                  NaN              NaN
# 3840               8             10                  NaN              NaN
# 3841               5             19                  NaN              NaN
# 3842               9              3                  NaN              NaN
# 3843               2              3                  NaN              NaN
# 3844               2              3                  NaN              NaN
#
#                                      description_google  print_type  \
# 3820                                                NaN         NaN
# 3821                                                NaN         NaN
# 3822                                                NaN         NaN
# 3823                                                NaN         NaN
# 3824  With his mom away, Ravi's birthday is shaping ...         NaN
# 3825                                                NaN         NaN
# 3826                                                NaN         NaN
# 3827  In 1937, F. Scott Fitzgerald was a troubled, u...         NaN
# 3828                                                NaN         NaN
# 3829                                                NaN         NaN
# 3830                                                NaN         NaN
# 3831                                                NaN         NaN
# 3832                                                NaN         NaN
# 3833                                                NaN         NaN
# 3834                                                NaN         NaN
# 3835                                                NaN         NaN
# 3836                                                NaN         NaN
# 3837                                                NaN         NaN
# 3838                                                NaN         NaN
# 3839                                                NaN         NaN
# 3840                                                NaN         NaN
# 3841                                                NaN         NaN
# 3842                                                NaN         NaN
# 3843                                                NaN         NaN
# 3844                                                NaN         NaN
#
#       page_count language country   saleability is_ebook  retail_price  \
# 3820         NaN      NaN     NaN           NaN      NaN           NaN
# 3821         NaN      NaN     NaN           NaN      NaN           NaN
# 3822       255.0       en      RU  NOT_FOR_SALE    False           NaN
# 3823         NaN      NaN     NaN           NaN      NaN           NaN
# 3824         NaN       en      RU  NOT_FOR_SALE    False           NaN
# 3825         NaN      NaN     NaN           NaN      NaN           NaN
# 3826         NaN      NaN     NaN           NaN      NaN           NaN
# 3827       406.0       en      RU      FOR_SALE     True         575.1
# 3828         NaN      NaN     NaN           NaN      NaN           NaN
# 3829         NaN      NaN     NaN           NaN      NaN           NaN
# 3830         NaN      NaN     NaN           NaN      NaN           NaN
# 3831         NaN      NaN     NaN           NaN      NaN           NaN
# 3832         NaN      NaN     NaN           NaN      NaN           NaN
# 3833         NaN      NaN     NaN           NaN      NaN           NaN
# 3834         NaN      NaN     NaN           NaN      NaN           NaN
# 3835         NaN      NaN     NaN           NaN      NaN           NaN
# 3836         NaN      NaN     NaN           NaN      NaN           NaN
# 3837         NaN      NaN     NaN           NaN      NaN           NaN
# 3838         NaN      NaN     NaN           NaN      NaN           NaN
# 3839         NaN      NaN     NaN           NaN      NaN           NaN
# 3840         NaN      NaN     NaN           NaN      NaN           NaN
# 3841       192.0       en      RU          FREE     True           NaN
# 3842         NaN      NaN     NaN           NaN      NaN           NaN
# 3843         NaN      NaN     NaN           NaN      NaN           NaN
# 3844         NaN      NaN     NaN           NaN      NaN           NaN
#
#      currency_code viewability public_domain epub_avaliable pdf_avaliable
# 3820           NaN         NaN           NaN            NaN           NaN
# 3821           NaN         NaN           NaN            NaN           NaN
# 3822           NaN    NO_PAGES         False          False         False
# 3823           NaN         NaN           NaN            NaN           NaN
# 3824           NaN    NO_PAGES         False          False         False
# 3825           NaN         NaN           NaN            NaN           NaN
# 3826           NaN         NaN           NaN            NaN           NaN
# 3827           RUB     PARTIAL         False           True          True
# 3828           NaN         NaN           NaN            NaN           NaN
# 3829           NaN         NaN           NaN            NaN           NaN
# 3830           NaN         NaN           NaN            NaN           NaN
# 3831           NaN         NaN           NaN            NaN           NaN
# 3832           NaN         NaN           NaN            NaN           NaN
# 3833           NaN         NaN           NaN            NaN           NaN
# 3834           NaN         NaN           NaN            NaN           NaN
# 3835           NaN         NaN           NaN            NaN           NaN
# 3836           NaN         NaN           NaN            NaN           NaN
# 3837           NaN         NaN           NaN            NaN           NaN
# 3838           NaN         NaN           NaN            NaN           NaN
# 3839           NaN         NaN           NaN            NaN           NaN
# 3840           NaN         NaN           NaN            NaN           NaN
# 3841           NaN   ALL_PAGES          True          False          True
# 3842           NaN         NaN           NaN            NaN           NaN
# 3843           NaN         NaN           NaN            NaN           NaN
# 3844           NaN         NaN           NaN            NaN           NaN

# %% [markdown]
# Для этих строк, помимо автора, нет и другой информации - можно их дропнуть

# %%
df2 = df2.drop(index = df2[df2["author"].isna()].index)
df2 = df2.reset_index(drop = True)
df2.shape
# Out:
# (3841, 31)

# %% [markdown]
# #### `ol_avg_rating`, `ol_rating_count`, `hardcover_rating`, `hardcover_ratings_count`, `users_count`

# %%
df2[["ol_avg_rating", "ol_rating_count", "hardcover_rating", "hardcover_ratings_count", "users_count"]].isna().sum()
# Out:
# ol_avg_rating              2794
# ol_rating_count            2463
# hardcover_rating            284
# hardcover_ratings_count     284
# users_count                 284
# dtype: int64

# %% [markdown]
# Рейтингам из open_library мы доверям больше, но там достаточно много пропусков, и большую часть строк пришлось бы не учитывать в анализе. Поэтому заполним пропуски в рейтинге `ol_avg_rating` рейтингом `hardcover_rating`, так как они формируются по одной и той же схеме - среднее оценка текста по оценкам по всем изданиям этого текста.

# %%
df2["ol_rating_count"] = np.where(df2["ol_avg_rating"].isna(), df2["hardcover_ratings_count"], df2["ol_rating_count"])
df2["ol_avg_rating"] = np.where(df2["ol_avg_rating"].isna(), df2["hardcover_rating"], df2["ol_avg_rating"])

# %%
df2 = df2.drop(columns=["hardcover_ratings_count", "hardcover_rating"])

# %% [markdown]
# Если рейтинг всё ещё не заполнен, то можем заполнить его 0

# %%
df2["ol_rating_count"] = df2["ol_rating_count"].fillna(0)
df2["ol_avg_rating"] = df2["ol_avg_rating"].fillna(0)

# %% [markdown]
# #### `price`, `release_year`, `age_group`, `publisher`

# %%
df2[["price", "release_year", "age_group", "publisher"]].isna().sum()
# Out:
# price              0
# release_year     467
# age_group       3765
# publisher          0
# dtype: int64

# %%
pd.DataFrame(df2["price"].value_counts()).head(10)
# Out:
#        count
# price
# 0.0     3841

# %%
pd.DataFrame(df2["publisher"].value_counts()).head(10)
# Out:
#                         count
# publisher
# Scholastic                143
# VIZ Media                 128
# Little, Brown             127
# Random House Audio        105
# Simon & Schuster Audio    103
# Simon & Schuster          103
# Grand Central             101
# Pinnacle                   77
# Random House               75
# Putnam                     75

# %% [markdown]
# Цена везде равна 0, так что столбец бесполезен, в `age_group` слишком много пропусков (98%) для анализа - дропаем эти столбцы

# %%
df2 = df2.drop(columns=["price", "age_group"])

# %% [markdown]
# Проверим "разумность" года

# %%
pd.DataFrame(df2["release_year"].value_counts().sort_index()).head(15)
# Out:
#               count
# release_year
# 1.0               3
# 3.0               1
# 10.0              3
# 11.0              1
# 13.0              1
# 15.0              1
# 19.0              2
# 28.0              1
# 29.0              1
# 101.0             1
# 1823.0            1
# 1826.0            1
# 1900.0            1
# 1920.0            1
# 1946.0            1

# %%
df2[df2["release_year"] < 1750].head(5)
# Out:
#                        title            author  ol_avg_rating  \
# 62           THE ROM-COMMERS  Katherine Center       3.000000
# 131             FIVE SURVIVE     Holly Jackson       3.400000
# 251           THE DUKE AND I       Julia Quinn       3.833333
# 291     THE WAY I USED TO BE       Amber Smith       3.965517
# 433  THE EMPEROR OF GLADNESS       Ocean Vuong       4.000000
#
#      ol_rating_count  users_count  release_year              publisher  \
# 62               1.0        365.0           1.0           St. Martin's
# 131             10.0        718.0          13.0              Delacorte
# 251             42.0          1.0          19.0         Recorded Books
# 291             29.0        289.0          29.0  Margaret K. McElderry
# 433              1.0        339.0          15.0          Penguin Press
#
#                                                 genres  \
# 62                               ['Fiction' 'Romance']
# 131  ['Fiction' 'Young Adult' 'Thriller' 'Young Adu...
# 251                              ['Fiction' 'Romance']
# 291                          ['Young Adult' 'Fiction']
# 433                       ['Fiction' 'LGBTQ' 'Poetry']
#
#                                            description  rank  rank_last_week  \
# 62   An aspiring screenwriter hopes to convince a f...    10               0
# 131  Six friends on a spring break road trip in an ...     1               2
# 251  Daphne Bridgerton’s reputation soars when she ...     1              12
# 291                                                NaN     4               0
# 433  A young man becomes the caretaker of an elderl...     2               0
#
#      weeks_on_list               categories    publisher_google  \
# 62               1              ['Fiction']         Hachette UK
# 131              5  ['Young Adult Fiction']     Delacorte Press
# 251              0        ['Great Britain']       Piatkus Books
# 291              0  ['Young Adult Fiction']  Simon and Schuster
# 433              1              ['Fiction']       Penguin Group
#
#                                     description_google  print_type  \
# 62   'A big hit of dopamine' EMILY GIFFIN *The inst...         NaN
# 131  #1 NEW YORK TIMES BESTSELLER • From the author...         NaN
# 251  The rakish Duke of Hastings will stop at nothi...         NaN
# 291  New York Times bestseller! In the tradition of...         NaN
# 433  The instant New York Times bestseller • Oprah’...         NaN
#
#      page_count language country   saleability is_ebook  retail_price  \
# 62        309.0       en      RU      FOR_SALE     True       1125.34
# 131       401.0       en      RU      FOR_SALE     True        737.16
# 251         0.0       en      RU  NOT_FOR_SALE    False           NaN
# 291       400.0       en      RU      FOR_SALE     True        718.48
# 433       417.0       en      RU  NOT_FOR_SALE    False           NaN
#
#     currency_code viewability public_domain epub_avaliable pdf_avaliable
# 62            RUB     PARTIAL         False           True         False
# 131           RUB     PARTIAL         False           True         False
# 251           NaN    NO_PAGES         False          False         False
# 291           RUB     PARTIAL         False           True         False
# 433           NaN     PARTIAL         False          False          True

# %% [markdown]
# Никакой зависисмости между этими ошибочными годами выпуска и реальными годами выпусками книг найдено не было, поэтому считаем, что мы не знаем год выпуска этих книг и ставим Nan

# %%
df2["release_year"] = np.where(df2["release_year"] < 1750, None, df2["release_year"])

# %% [markdown]
# #### `genres`, `description`

# %%
df2[["genres", "description"]].isna().sum()
# Out:
# genres         284
# description    565
# dtype: int64

# %%
df2["genres"] = df2["genres"].fillna("'[]'")

# %%
df2["genres"] = df2["genres"].str.split("'").str[1::2]

# %%
arr = df2["genres"].explode()
word_counts = Counter(arr.str.strip())
word_counts_df = (pd.DataFrame(word_counts.items(), columns=["genre", "count"]).sort_values("count", ascending=False))

# %%
word_counts_df.head(15)
# Out:
#                         genre  count
# 5                     Fiction   1444
# 1                 Young Adult    928
# 0                     Fantasy    869
# 14                  Adventure    741
# 6                     Romance    361
# 13                    Mystery    333
# 22                   Thriller    327
# 15                     Comics    319
# 4            Juvenile Fiction    295
# 23                         []    284
# 16            Science Fiction    235
# 38                        War    227
# 2                       LGBTQ    222
# 41  Biography & Autobiography    209
# 21                   Suspense    200

# %%
genres10 = ["Fiction", "Young Adult", "Fantasy", "Adventure", "Romance", "Mystery", "Thriller", "Comics", "Juvenile Fiction", "Science Fiction"]

for genre in genres10:
    df2[f"genre_{genre}"] = df2["genres"].apply(
        lambda x: genre in x if isinstance(x, list) else False
    )

# %% [markdown]
# #### `rank`, `rank_last_week`, `weeks_on_list`

# %%
df2[["rank", "rank_last_week", "weeks_on_list"]].isna().sum()
# Out:
# rank              0
# rank_last_week    0
# weeks_on_list     0
# dtype: int64

# %% [markdown]
# #### `categories`, `gb_publisher`, `description`

# %%
df2.head(5)
# Out:
#                         title         author  ol_avg_rating  ol_rating_count  \
# 0     LOST IN THE NEVER WOODS   Aiden Thomas            1.0              1.0
# 1                THE DEFENDER      Ana Huang            1.0              1.0
# 2    GREAT BIG BEAUTIFUL LIFE    Emily Henry            1.0              1.0
# 3  KAMALA AND MAYA'S BIG IDEA   Meena Harris            1.0              1.0
# 4        HOW ARE YOU, REALLY?  Jenna Kutcher            1.0              1.0
#
#    users_count release_year      publisher  \
# 0        249.0       2000.0    Swoon Reads
# 1         31.0       2025.0          Bloom
# 2        704.0       2025.0  Penguin Audio
# 3          6.0       2020.0  Balzer + Bray
# 4         12.0       2022.0     Dey Street
#
#                                               genres  \
# 0  [Fantasy, Young Adult, LGBTQ, Young Adult Fict...
# 1                                          [Fiction]
# 2  [Fiction, Romance, Contemporary Romance, romco...
# 3                                                 []
# 4                                                 []
#
#                                          description  rank  rank_last_week  \
# 0  Wendy assists Peter Pan to find missing childr...     4               0
# 1  The second book in the Gods of the Game series...     1               0
# 2  A writer looking for her big break competes ag...     1               0
# 3  Two sisters turn their empty apartment courtya...     5               0
# 4                                                NaN     7               0
#
#    weeks_on_list               categories publisher_google  \
# 0              1                      NaN              NaN
# 1              1                      NaN              NaN
# 2              0              ['Fiction']     Random House
# 3              1     ['Juvenile Fiction']    HarperCollins
# 4              0  ['Body, Mind & Spirit']    HarperCollins
#
#                                   description_google  print_type  page_count  \
# 0                                                NaN         NaN         NaN
# 1                                                NaN         NaN         NaN
# 2  The dazzling new love story and Reese Withersp...         NaN       363.0
# 3  INSPIRED BY A TRUE STORY FROM THE CHILDHOOD OF...         NaN        37.0
# 4  AN INSTANT NEW YORK TIMES BESTSELLER "The perf...         NaN       271.0
#
#   language country saleability is_ebook  retail_price currency_code  \
# 0      NaN     NaN         NaN      NaN           NaN           NaN
# 1      NaN     NaN         NaN      NaN           NaN           NaN
# 2       en      RU    FOR_SALE     True       2138.54           RUB
# 3       en      RU    FOR_SALE     True       1032.34           RUB
# 4       en      RU    FOR_SALE     True       1521.74           RUB
#
#   viewability public_domain epub_avaliable pdf_avaliable  genre_Fiction  \
# 0         NaN           NaN            NaN           NaN          False
# 1         NaN           NaN            NaN           NaN           True
# 2     PARTIAL         False           True         False           True
# 3     PARTIAL         False           True          True          False
# 4     PARTIAL         False           True         False          False
#
#    genre_Young Adult  genre_Fantasy  genre_Adventure  genre_Romance  \
# 0               True           True            False          False
# 1              False          False            False          False
# 2              False          False            False           True
# 3              False          False            False          False
# 4              False          False            False          False
#
#    genre_Mystery  genre_Thriller  genre_Comics  genre_Juvenile Fiction  \
# 0          False           False         False                    True
# 1          False           False         False                   False
# 2          False           False         False                   False
# 3          False           False         False                   False
# 4          False           False         False                   False
#
#    genre_Science Fiction
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False

# %%
df2[["categories", "publisher_google", "description_google"]].isna().sum()
# Out:
# categories            1277
# publisher_google      1393
# description_google    1267
# dtype: int64

# %% [markdown]
# Пропусков много, так как эти поля были взяты из апи гугл книг, а не все книги удалось там найти
# В столбце `categories` указана везде одна основная "категория" книги. Кодировка этого столбца через OHE будет излишней на этапе EDA, поэтому просто приведем её к более удобному строковому формату

# %%
df2["categories"] = df2["categories"].str.lower().str[2:-2]

# %% [markdown]
# #### `print_type`, `gb_pages`, `language`

# %%
df2[["print_type", "page_count", "language"]].isna().sum()
# Out:
# print_type    3841
# page_count    1179
# language      1161
# dtype: int64

# %%
pd.DataFrame(df2["language"].value_counts())
# Out:
#           count
# language
# en         2660
# sv            3
# id            3
# fr            3
# pl            2
# de            2
# ro            2
# pt-BR         1
# nl            1
# fi            1
# es            1
# it            1

# %% [markdown]
# print_type - пустой, удаляем pages_count - в этот раз оставляем, так как другого количества страниц у нас нет language - 99.2% имеют значение "ru", а других категорий слишком мало, этот столбец не подходит для анализа

# %%
df2 = df2.drop(columns=["print_type", "language"])
df2.shape
# Out:
# (3841, 35)

# %% [markdown]
# #### `country`, `saleability`, `is_ebook`, `retail_price`, `currency_code`, `viewability`,

# %%
df2[["country", "saleability", "is_ebook", "retail_price", "currency_code", "viewability", "public_domain"]].isna().sum()
# Out:
# country          1161
# saleability      1161
# is_ebook         1161
# retail_price     2422
# currency_code    2422
# viewability      1161
# public_domain    1161
# dtype: int64

# %% [markdown]
# 1161 пропусков это кол-во книг, которые не были найдены в api гугл книг. У некоторых так же отдельно не были найдены только цены

# %%
pd.DataFrame(df2["country"].value_counts())
# Out:
#          count
# country
# RU        2680

# %% [markdown]
# Все страны - Россия, в этот раз иноагентов нет

# %%
df2 = df2.drop(columns=["country"])

# %%
pd.DataFrame(df2["saleability"].value_counts()) # - оставляем
# Out:
#               count
# saleability
# FOR_SALE       1419
# NOT_FOR_SALE   1261

# %% [markdown]
# Столбцы с Nan можно заполнить "NOT_FOR_SALE" книга не была найдена в api гугл книг, значит, в гугл книгах она не продается

# %%
df2["saleability"] = df2["saleability"].fillna("NOT_FOR_SALE")

# %%
pd.DataFrame(df2["is_ebook"].value_counts()) # - оставляем
# Out:
#           count
# is_ebook
# True       1419
# False      1261

# %%
pd.DataFrame(df2["currency_code"].value_counts())
# Out:
#                count
# currency_code
# RUB             1419

# %%
pd.DataFrame(df2["viewability"].value_counts()) # - оставляем
# Out:
#              count
# viewability
# PARTIAL       1949
# NO_PAGES       730
# ALL_PAGES        1

# %%
df2["viewability"] = df2["viewability"].fillna("NO_PAGES")

# %%
pd.DataFrame(df2["public_domain"].value_counts())
# Out:
#                count
# public_domain
# False           2680

# %% [markdown]
# Все значения - False. Дропаем признак

# %%
df2 = df2.drop(columns=["public_domain"])

# %% [markdown]
# #### `epub_avaliable`, `pdf_avaliable`

# %%
df2[["epub_avaliable", "pdf_avaliable"]].isna().sum()
# Out:
# epub_avaliable    1161
# pdf_avaliable     1161
# dtype: int64

# %% [markdown]
# Показывают в каком формате книга доступна для прочтения, если у неё есть бесплатные страницы для прочтения. Если книга не была найдена, то оба формата недоступны. Можно заполнить Nan через False

# %%
df2["epub_avaliable"] = df2["epub_avaliable"].fillna(False)
df2["pdf_avaliable"] = df2["pdf_avaliable"].fillna(False)
df2
# Out:
# /var/folders/4z/3fr35yyn2w34chm4bp6ywypc0000gn/T/ipykernel_62228/268001764.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2["epub_avaliable"] = df2["epub_avaliable"].fillna(False)
# /var/folders/4z/3fr35yyn2w34chm4bp6ywypc0000gn/T/ipykernel_62228/268001764.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df2["pdf_avaliable"] = df2["pdf_avaliable"].fillna(False)
#                                             title           author  \
# 0                         LOST IN THE NEVER WOODS     Aiden Thomas
# 1                                    THE DEFENDER        Ana Huang
# 2                        GREAT BIG BEAUTIFUL LIFE      Emily Henry
# 3                      KAMALA AND MAYA'S BIG IDEA     Meena Harris
# 4                            HOW ARE YOU, REALLY?    Jenna Kutcher
# ...                                           ...              ...
# 3836                     JESSI RAMSEY, PET-SITTER    Ann M. Martin
# 3837  THE OVERTHINKER'S GUIDE TO MAKING DECISIONS    Joseph Nguyen
# 3838                                STRONG GROUND      Brené Brown
# 3839                               KINGDOM OF ASH    Sarah J. Maas
# 3840                          KAGURABACHI, VOL. 4  Takeru Hokazono
#
#       ol_avg_rating  ol_rating_count  users_count release_year  \
# 0          1.000000              1.0        249.0       2000.0
# 1          1.000000              1.0         31.0       2025.0
# 2          1.000000              1.0        704.0       2025.0
# 3          1.000000              1.0          6.0       2020.0
# 4          1.000000              1.0         12.0       2022.0
# ...             ...              ...          ...          ...
# 3836       3.250000              8.0         15.0       1989.0
# 3837       0.000000              0.0         16.0       2025.0
# 3838       0.000000              0.0          1.0       2025.0
# 3839       4.509124            822.0       1718.0       2018.0
# 3840       4.500000              4.0          8.0       2024.0
#
#             publisher                                             genres  \
# 0         Swoon Reads  [Fantasy, Young Adult, LGBTQ, Young Adult Fict...
# 1               Bloom                                          [Fiction]
# 2       Penguin Audio  [Fiction, Romance, Contemporary Romance, romco...
# 3       Balzer + Bray                                                 []
# 4          Dey Street                                                 []
# ...               ...                                                ...
# 3836       Scholastic  [Friendship, Fiction, Young Adult, Juvenile Fi...
# 3837   Authors Equity                                        [Self-Help]
# 3838     Random House                                                 []
# 3839  Audible Studios  [Fantasy, Young Adult, Science Fiction & Fanta...
# 3840        VIZ Media                     [Fantasy, Young Adult, Comics]
#
#                                             description  rank  rank_last_week  \
# 0     Wendy assists Peter Pan to find missing childr...     4               0
# 1     The second book in the Gods of the Game series...     1               0
# 2     A writer looking for her big break competes ag...     1               0
# 3     Two sisters turn their empty apartment courtya...     5               0
# 4                                                   NaN     7               0
# ...                                                 ...   ...             ...
# 3836  The 18th book in the Baby-Sitters Club graphic...     7               0
# 3837                                                NaN     6               0
# 3838                                                NaN     3               2
# 3839  The seventh book in the Throne of Glass series...    11               0
# 3840  Chihiro must get past the guards at an auction...    13               0
#
#       weeks_on_list           categories       publisher_google  \
# 0                 1                  NaN                    NaN
# 1                 1                  NaN                    NaN
# 2                 0              fiction           Random House
# 3                 1     juvenile fiction          HarperCollins
# 4                 0  body, mind & spirit          HarperCollins
# ...             ...                  ...                    ...
# 3836              3                  NaN                    NaN
# 3837              2            self-help                    NaN
# 3838              2                  NaN                    NaN
# 3839              0              fiction  Bloomsbury Publishing
# 3840              1                  NaN                    NaN
#
#                                      description_google  page_count  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2     The dazzling new love story and Reese Withersp...       363.0
# 3     INSPIRED BY A TRUE STORY FROM THE CHILDHOOD OF...        37.0
# 4     AN INSTANT NEW YORK TIMES BESTSELLER "The perf...       271.0
# ...                                                 ...         ...
# 3836                                                NaN         NaN
# 3837  We always intuitively know what to do deep dow...         0.0
# 3838                                                NaN         NaN
# 3839  Together they will rise. Or together they will...       998.0
# 3840                                                NaN         NaN
#
#        saleability is_ebook  retail_price currency_code viewability  \
# 0     NOT_FOR_SALE      NaN           NaN           NaN    NO_PAGES
# 1     NOT_FOR_SALE      NaN           NaN           NaN    NO_PAGES
# 2         FOR_SALE     True       2138.54           RUB     PARTIAL
# 3         FOR_SALE     True       1032.34           RUB     PARTIAL
# 4         FOR_SALE     True       1521.74           RUB     PARTIAL
# ...            ...      ...           ...           ...         ...
# 3836  NOT_FOR_SALE      NaN           NaN           NaN    NO_PAGES
# 3837  NOT_FOR_SALE    False           NaN           NaN    NO_PAGES
# 3838  NOT_FOR_SALE      NaN           NaN           NaN    NO_PAGES
# 3839      FOR_SALE     True        900.11           RUB     PARTIAL
# 3840  NOT_FOR_SALE      NaN           NaN           NaN    NO_PAGES
#
#       epub_avaliable  pdf_avaliable  genre_Fiction  genre_Young Adult  \
# 0              False          False          False               True
# 1              False          False           True              False
# 2               True          False           True              False
# 3               True           True          False              False
# 4               True          False          False              False
# ...              ...            ...            ...                ...
# 3836           False          False           True               True
# 3837           False          False          False              False
# 3838           False          False          False              False
# 3839           False           True           True               True
# 3840           False          False          False               True
#
#       genre_Fantasy  genre_Adventure  genre_Romance  genre_Mystery  \
# 0              True            False          False          False
# 1             False            False          False          False
# 2             False            False           True          False
# 3             False            False          False          False
# 4             False            False          False          False
# ...             ...              ...            ...            ...
# 3836          False            False          False          False
# 3837          False            False          False          False
# 3838          False            False          False          False
# 3839           True             True           True          False
# 3840           True            False          False          False
#
#       genre_Thriller  genre_Comics  genre_Juvenile Fiction  \
# 0              False         False                    True
# 1              False         False                   False
# 2              False         False                   False
# 3              False         False                   False
# 4              False         False                   False
# ...              ...           ...                     ...
# 3836           False         False                    True
# 3837           False         False                   False
# 3838           False         False                   False
# 3839           False         False                   False
# 3840           False          True                   False
#
#       genre_Science Fiction
# 0                     False
# 1                     False
# 2                     False
# 3                     False
# 4                     False
# ...                     ...
# 3836                  False
# 3837                  False
# 3838                  False
# 3839                  False
# 3840                  False
#
# [3841 rows x 33 columns]

# %% [markdown]
# ### Univariate analysis

# %% [markdown]
# Рассмотрим распределение числовых признаков

# %% [markdown]
# `ol_avg_rating`

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df2['ol_avg_rating'], bins=30, kde=True, color=sns.color_palette("magma")[1])
plt.xlabel('Средняя оценка')
plt.ylabel('Количество книг')
plt.title('Распределение оценок c open_library и hardcover', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# Чаще всего книги имеют оценку 3-5, что логично, так как эти книги попали в список бестселлеров. Стоит отметить, что книг с целой оценкой (0-1-2-3-4-5) больше, чем с дробными, это происходит, так как есть много книг с малым количеством оценок, где 1-3 пользователя сошлись на одинаковой оценке.
#
# Около 700 книг с 0 это книги, у которых нет рейтинга ни в openlibrary, ни в hardcover

# %% [markdown]
# `ol_rating_count`

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df2['ol_rating_count'], bins=30, kde=True, color=sns.color_palette("magma")[1])
plt.xlabel('Количество оценок')
plt.ylabel('Количество книг')
plt.title('Распределение количества оценок c open_library и hardcover', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.show()

# %%
first_quartile = df2['ol_rating_count'].describe()['25%']
third_quartile = df2['ol_rating_count'].describe()['75%']
iqr = third_quartile - first_quartile
condition1 = (df2['ol_rating_count'] > (first_quartile - 3 * iqr)) & (df2['ol_rating_count'] < (third_quartile + 3 * iqr))
print(first_quartile, third_quartile)
# Out:
# 1.0 18.0

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df2[condition1]['ol_rating_count'], bins=30, kde=True, color=sns.color_palette("magma")[1])
plt.xlabel('Количество оценок')
plt.ylabel('Количество книг')
plt.title('Распределение количества оценок c open_library и hardcover без выбросов', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# Можно увидеть, что у 75% книг меньше 18 отзывов, то есть, большинство книг-беселлеров не такие популярные на open_library и hardcover

# %% [markdown]
# `users_count`

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df2['users_count'], bins=30, kde=True, color=sns.color_palette("magma")[1])
plt.xlabel('Количество пользователей, которые добавили книгу в библиотеку')
plt.ylabel('Количество книг')
plt.title('Распределение количества пользователей, которые добавили книгу в библиотеку', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.show()

# %%
first_quartile = df2['users_count'].describe()['25%']
third_quartile = df2['users_count'].describe()['75%']
iqr = third_quartile - first_quartile
condition2 = (df2['users_count'] > (first_quartile - 3 * iqr)) & (df2['users_count'] < (third_quartile + 3 * iqr))
print(first_quartile, third_quartile)
# Out:
# 6.0 168.0

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df2[condition2]['users_count'], bins=30, kde=True, color=sns.color_palette("magma")[1])
plt.xlabel('Количество пользователей, которые добавили книгу в библиотеку')
plt.ylabel('Количество книг')
plt.title('Распределение количества пользователей, \n которые добавили книгу в библиотеку без выбросов', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# Видим похожую картину, как и в количестве оценок, большую часть книг добавило совсем немного пользователей. При этом больше пользоваталей добавили книгу, чем оценили её, что логично, так как сначала книгу надо прочитать.

# %% [markdown]
# `release_year`

# %%
df2['release_year'].astype(float).describe()
# Out:
# count    3359.000000
# mean     2019.597499
# std         9.036189
# min      1823.000000
# 25%      2020.000000
# 50%      2021.000000
# 75%      2023.000000
# max      2026.000000
# Name: release_year, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df2['release_year'], bins=30, kde=True, color=sns.color_palette("magma")[2])
plt.xlabel('Год')
plt.ylabel('Количество книг')
plt.title('Распределение публикаций книг по годам', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# Рассмотрим отдельно книги, опубликованные после 2000 года

# %%
df2_after2000 = df2[df2['release_year']>= 2000]

# %%
year_counts = df2_after2000["release_year"].value_counts().sort_index().reset_index()
year_counts = pd.DataFrame(year_counts)
year_counts["release_year"] = year_counts["release_year"].astype(int)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=year_counts, x="release_year", y="count", color=sns.color_palette("magma")[2])
plt.xlabel('Год')
plt.ylabel('Количество книг')
plt.title('Распределение публикаций книг по годам после 2000', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.xticks(rotation=45, fontsize=8)
plt.show()

# %% [markdown]
# О ужас, в 2026 году было выпущено в несколько раз меньше книг, чем в 2025-ом, о нет, литературная индустрия рушится...
#
# Ну или просто анализ проводится на начало апреля 2026 года :))
#
# По графику видно, что в бестселлеры new york times в основном попадают очень современные произведения, после 2019 года. При этом в 2020-2025 годах было выпущено схожее количество книг, попавших в бестселлеры, около 400 в каждый из годов

# %% [markdown]
# `rank`, `rank_last_week`, `weeks_on_list`

# %%
rank_counts = df2["rank"].value_counts().sort_index().reset_index()
rank_counts = pd.DataFrame(rank_counts)
rank_counts["rank"] = rank_counts["rank"].astype(int)

# %%
rank_last_counts = df2["rank_last_week"].value_counts().sort_index().reset_index()
rank_last_counts = pd.DataFrame(rank_last_counts)
rank_last_counts["rank_last_week"] = rank_last_counts["rank_last_week"]

# %%
first_quartile = df2['weeks_on_list'].describe()['25%']
third_quartile = df2['weeks_on_list'].describe()['75%']
iqr = third_quartile - first_quartile
condition3 = (df2['weeks_on_list'] > (first_quartile - 3 * iqr)) & (df2['weeks_on_list'] < (third_quartile + 3 * iqr))
print(first_quartile, third_quartile)
# Out:
# 0.0 2.0

# %%
weeks_counts = df2[condition3]["weeks_on_list"].value_counts().sort_index().reset_index()
weeks_counts = pd.DataFrame(weeks_counts)
weeks_counts["weeks_on_list"] = weeks_counts["weeks_on_list"]

# %%
plt.figure(figsize=(8, 6))

plt.subplot(3, 1, 1)
sns.barplot(data=rank_counts, x="rank", y="count", color=sns.color_palette("magma")[3])
plt.xlabel('Место в рейтинге')
plt.ylabel('Количество книг')
plt.title('Количество книг разных рангов', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.xticks(fontsize=10)

plt.subplot(3, 1, 2)
sns.barplot(data=rank_last_counts, x="rank_last_week", y="count", color=sns.color_palette("magma")[4])
plt.xlabel('Место в рейтинге на предыдущей неделе')
plt.ylabel('Количество книг')
plt.title('Количество книг разных рангов на предыдущей неделе', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.xticks(fontsize=10)

plt.subplot(3, 1, 3)
sns.barplot(data=weeks_counts, x="weeks_on_list", y="count", color=sns.color_palette("magma")[5])
plt.xlabel('Кол-во недель в рейтинге')
plt.ylabel('Количество книг')
plt.title('Распределение книг по кол-ву недель в рейтинге', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.xticks(fontsize=10)

plt.tight_layout() # о нет, очень страшно
plt.show()

# %% [markdown]
# В датасете осталось больше всего книг с 7-10 местом в рейтинге бестселлеров.
#
# Преимущественное большинство входили в рейтинг бестселлеров в первый раз, при этом около трети попадали в рейтинг ранее

# %%
first_quartile = df2['page_count'].describe()['25%']
third_quartile = df2['page_count'].describe()['75%']
iqr = third_quartile - first_quartile
condition4 = (df2['page_count'] > (first_quartile - 3 * iqr)) & (df2['page_count'] < (third_quartile + 3 * iqr))
print(first_quartile, third_quartile)
condition5 = (df2["page_count"] != 0)
# Out:
# 175.25 386.0

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df2[condition4 & condition5]['page_count'], bins=50, kde=True, color=sns.color_palette("magma")[2])
plt.xlabel('Кол-во страниц')
plt.ylabel('Количество книг')
plt.title('Распределение книг по количеству страниц', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.show()

# %%
from scipy.stats import shapiro

stat, p = shapiro(df2[condition4 & condition5]['page_count'])

# %%
stat, p
# Out:
# (np.float64(0.9621007196377466), np.float64(1.0679722440245312e-23))

# %% [markdown]
# p < 0.05 - не отклоняем нулевую гипотезу, количество страниц в книгах распределено нормально

# %% [markdown]
# `publisher`, `publisher_google`

# %%
top_10_publisher = df2["publisher"].value_counts().reset_index()[0:10]

# %%
top_10_publisher_google = df2["publisher_google"].value_counts().reset_index()[0:10]
top_10_publisher_google
# Out:
#             publisher_google  count
# 0         Simon and Schuster    272
# 1                Hachette UK    268
# 2               Random House    222
# 3                    Penguin    161
# 4              HarperCollins    149
# 5              VIZ Media LLC     73
# 6            Scholastic Inc.     59
# 7             Pinnacle Books     55
# 8  National Geographic Books     45
# 9              Pan Macmillan     41

# %%
plt.figure(figsize=(15, 15))

plt.subplot(2, 1, 1)
sns.barplot(data=top_10_publisher, x="publisher", y="count", color=sns.color_palette("magma")[3])
plt.xlabel('Издательство')
plt.ylabel('Количество книг')
plt.title('Топ 10 издательств по количеству книг', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.xticks(rotation=90, fontsize=8)

plt.subplot(2, 1, 2)
sns.barplot(data=top_10_publisher_google, x="publisher_google", y="count", color=sns.color_palette("magma")[4])
plt.xlabel('Издательство по мнению гугл книг')
plt.ylabel('Количество книг')
plt.title('Топ 10 издательств (гугл книги) по количеству книг ', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.xticks(rotation=90, fontsize=8)

plt.tight_layout() # о нет, стало ещё страшнее
plt.show()

# %% [markdown]
# Многие издательства в топ 10 повторяются, но при этом не совпадают идеально. Например, "Simon & Schuster" в new york times делится на два - "Simon & Schuster" и "Simon & Schuster Audio". У некоторых книг издательства в принципе не совпадают так как new york times и google books api ссылаются на разные издания одного и того же текста.

# %% [markdown]
# `categories`

# %%
top_10_categories = df2["categories"].value_counts().reset_index()[0:10]

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=top_10_categories, x="categories", y="count", color=sns.color_palette("magma")[4])
plt.xlabel('Категория')
plt.ylabel('Количество книг')
plt.title('Топ 10 категорий', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.xticks(rotation=90, fontsize=8)
plt.show()

# %% [markdown]
# Большинство книг имеют категорию "художественная литература", в неё так же входят `juvenile fiction` и `young adult fiction`.
# Так же популярны биографии, комиксы, исторические, политические и экономические книги, рецепты и медицина.

# %% [markdown]
# `saleability`

# %%
plt.figure(figsize=(5, 4))
sns.barplot(df2["saleability"].value_counts().reset_index(), x="saleability", y="count", color=sns.color_palette("magma")[4])
plt.xlabel('Статус продажи')
plt.ylabel('Количество книг')
plt.title('Количество книг с разным статусом продажи', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.xticks(rotation=0, fontsize=8)
plt.show()

# %% [markdown]
# `is_ebook`

# %%
plt.figure(figsize=(5, 4))
sns.barplot(df2["is_ebook"].value_counts().reset_index(), x="is_ebook", y="count", color=sns.color_palette("magma")[0])
plt.xlabel('Статус продажи')
plt.ylabel('Количество книг')
plt.title('Количество книг с разным статусом продажи', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.xticks(rotation=0, fontsize=8)
plt.show()

# %% [markdown]
# `retail_price`

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df2['retail_price'], bins=30, kde=True, color=sns.color_palette("magma")[4])
plt.xlabel('Цена книги в google books')
plt.ylabel('Количество книг')
plt.title('Распределение цен книг в google books', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.show()

# %%
first_quartile = df2['retail_price'].describe()['25%']
third_quartile = df2['retail_price'].describe()['75%']
iqr = third_quartile - first_quartile
condition6 = (df2['retail_price'] > (first_quartile - 3 * iqr)) & (df2['retail_price'] < (third_quartile + 3 * iqr))

# %% [markdown]
# ### Multivariate analysis

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df2[condition6]['retail_price'], bins=30, kde=True, color=sns.color_palette("magma")[4])
plt.xlabel('Цена книги в google books')
plt.ylabel('Количество книг')
plt.title('Распределение цен книг в google books без выбросов', fontsize=12, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.show()

# %%
numeric_data = df2[["ol_avg_rating", "users_count", "genre_Fiction", "genre_Young Adult", "genre_Fantasy", "genre_Adventure",
                     "genre_Romance", "genre_Mystery", "genre_Thriller", "genre_Comics", "genre_Juvenile Fiction", "genre_Science Fiction"]]
corr_matrix = numeric_data.corr(method='spearman')

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='magma', linewidths=0.5)

plt.title('Матрица корреляций числовых и бинарных признаков', fontsize=16)
plt.tight_layout()
plt.show()

# %%
corr_matrix = df2[['ol_avg_rating', 'ol_rating_count', 'users_count', 'release_year', 'rank', 'rank_last_week', 'page_count', 'is_ebook', 'retail_price', 'epub_avaliable']].corr()

sns.heatmap(corr_matrix, square=True, annot=True, fmt='.2f')

plt.title('Матрица корреляции признаков')
plt.show()

# %%
genres = ['genre_Fiction', 'genre_Young Adult', 'genre_Fantasy', 'genre_Adventure', 'genre_Romance', 
          'genre_Mystery', 'genre_Thriller', 'genre_Comics', 'genre_Juvenile Fiction', 'genre_Science Fiction']


mean_price = []
for genre in genres:
    mean_pr = df2[df2[genre] == 1]['ol_avg_rating'].mean()
    mean_price.append(mean_pr)

plt.figure(figsize=(10, 5))
plt.bar(genres, mean_price, color=sns.color_palette("magma")[4])
plt.title('Средний рейтинг по жанрам')
plt.xlabel('Жанр')
plt.ylabel('Средний рейтинг')
plt.xticks(rotation=45)
plt.show()

# %%
genres = ['genre_Fiction', 'genre_Young Adult', 'genre_Fantasy', 'genre_Adventure', 'genre_Romance', 
          'genre_Mystery', 'genre_Thriller', 'genre_Comics', 'genre_Juvenile Fiction', 'genre_Science Fiction']


mean_price = []
for genre in genres:
    mean_pr = df2[df2[genre] == 1]['retail_price'].mean()
    mean_price.append(mean_pr)

plt.figure(figsize=(10, 5))
plt.bar(genres, mean_price, color=sns.color_palette("magma")[4])
plt.title('Средняя цена по жанрам')
plt.xlabel('Жанр')
plt.ylabel('Средняя цена')
plt.xticks(rotation=45)
plt.show()

# %%
plt.scatter(df2['ol_rating_count'], df2['users_count'])

plt.xlabel('Число пользователей, оценивших книгу')
plt.ylabel('Число пользователей, сохранивших книгу')
plt.title('Зависимость числа пользователей, оценивших книгу, от пользователей, сохранивших книгу', fontweight='bold')
plt.show()

# %%
df2[df2['is_ebook'] != True]['page_count'].value_counts()
# Out:
# page_count
# 0.0      418
# 320.0     25
# 352.0     21
# 368.0     16
# 321.0     16
#         ...
# 387.0      1
# 146.0      1
# 359.0      1
# 592.0      1
# 380.0      1
# Name: count, Length: 316, dtype: int64

# %%
plt.figure(figsize=(8, 6))
plt.boxplot([df2[df2['is_ebook'] == True]['page_count'].dropna(), df2[df2['is_ebook'] != True]['page_count'].dropna()], labels=['электронная', 'бумажная'])

plt.xlabel('Тип книги')
plt.ylabel('Количество страниц')
plt.title('Распределение количества страниц у электронных и бумажных книг', fontweight='bold')
plt.show()
# Out:
# /var/folders/4z/3fr35yyn2w34chm4bp6ywypc0000gn/T/ipykernel_62228/4138052501.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df2[df2['is_ebook'] == True]['page_count'].dropna(), df2[df2['is_ebook'] != True]['page_count'].dropna()], labels=['электронная', 'бумажная'])

# %%
plt.boxplot([df2[(df2['is_ebook'] == True) & (df2['page_count'] < 2000)]['page_count'].dropna(), df2[df2['is_ebook'] != True]['page_count'].dropna()], labels=['электронная', 'бумажная'])

plt.xlabel('Тип книги')
plt.ylabel('Количество страниц')
plt.title('Распределение количества страниц у электронных и бумажных книг', fontweight='bold')
plt.show()
# Out:
# /var/folders/4z/3fr35yyn2w34chm4bp6ywypc0000gn/T/ipykernel_62228/4156529564.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df2[(df2['is_ebook'] == True) & (df2['page_count'] < 2000)]['page_count'].dropna(), df2[df2['is_ebook'] != True]['page_count'].dropna()], labels=['электронная', 'бумажная'])

# %%
plt.scatter(df2['page_count'], df2['retail_price'])

plt.xlabel('Число страниц')
plt.ylabel('Цена')
plt.title('Зависимость цены от количества страниц', fontweight='bold')
plt.show()

# %%
plt.scatter(df2[df2['retail_price'] < 4000]['page_count'], df2[df2['retail_price'] < 4000]['retail_price'])

plt.xlabel('Число страниц')
plt.ylabel('Цена')
plt.title('Зависимость цены от количества страниц', fontweight='bold')
plt.show()

# %%
plt.boxplot([df2[(df2['epub_avaliable'] == True) & (df2['page_count'] < 2000)]['page_count'].dropna(), df2[df2['epub_avaliable'] != True]['page_count'].dropna()], labels=['epub', 'не epub'])

plt.xlabel('Доступность epub')
plt.ylabel('Количество страниц')
plt.title('Распределение количества страниц у книг с epub и без', fontweight='bold')
plt.show()
# Out:
# /var/folders/4z/3fr35yyn2w34chm4bp6ywypc0000gn/T/ipykernel_62228/1463652346.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df2[(df2['epub_avaliable'] == True) & (df2['page_count'] < 2000)]['page_count'].dropna(), df2[df2['epub_avaliable'] != True]['page_count'].dropna()], labels=['epub', 'не epub'])

# %%
plt.bar(['is_ebook=True', 'is_ebook=False'], [len(df2[(df2['is_ebook'] == True) & (df2['epub_avaliable'] == True)]), len(df2[(df2['is_ebook'] == False) & (df2['epub_avaliable'] == True)])])
plt.bar(['is_ebook=True', 'is_ebook=False'], [len(df2[(df2['is_ebook'] == True) & (df2['epub_avaliable'] == False)]), len(df2[(df2['is_ebook'] == False) & (df2['epub_avaliable'] == False)])])

plt.ylabel('Количество книг')
plt.title('epub_available в зависимости от is_ebook', fontweight='bold')
plt.legend()
plt.show()
# Out:
# /var/folders/4z/3fr35yyn2w34chm4bp6ywypc0000gn/T/ipykernel_62228/2453963017.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.scatter(df2['rank_last_week'], df2['rank'])
plt.plot([0, max(df2['rank'].max(), df2['rank_last_week'].max())], [0, max(df2['rank'].max(), df2['rank_last_week'].max())], color='red')

plt.xlabel('Ранг на прошлой неделе')
plt.ylabel('Текущий ранг')
plt.title('Сравнение рангов', fontweight='bold')
plt.show()

# %%
avg_rating = df2[df2['ol_avg_rating'] > 0].groupby('release_year')['ol_avg_rating'].mean()

plt.plot(avg_rating.index, avg_rating.values)

plt.xlabel('Год выпуска')
plt.ylabel('Средний рейтинг')
plt.title('Средний пользовательский рейтинг по годам', fontweight='bold')
plt.show()

# %%
avg_rating = df2[(df2['ol_avg_rating'] > 0) & (df2['release_year'] > 1960)].groupby('release_year')['ol_avg_rating'].mean()

plt.plot(avg_rating.index, avg_rating.values)

plt.xlabel('Год выпуска')
plt.ylabel('Средний рейтинг')
plt.title('Средний пользовательский рейтинг по годам', fontweight='bold')
plt.show()

# %% [markdown]
# Сравнение рейтингов

# %%
sns.kdeplot(df1['rating'], label="Рейтинг в Литрес")
sns.kdeplot(df2['ol_avg_rating'], label="Рейтинг в OpenLibrary и Hardcover")
plt.legend()
plt.show()

# %% [markdown]
# Сравнение количества оценок

# %%
sns.kdeplot(df1['reviews_count'], label="Количество оценок в Литрес")
sns.kdeplot(df2['ol_rating_count'], label="Количество оценок в OpenLibrary и Hardcover")
plt.legend()
plt.show()

# %% [markdown]
# Приблизим этот график для более удобного анализа

# %%
sns.kdeplot(df1[df1['reviews_count'] < 100]['reviews_count'], label="Количество оценок в Литрес")
sns.kdeplot(df2[df2['ol_rating_count'] < 100]['ol_rating_count'], label="Количество оценок в OpenLibrary и Hardcover")
plt.legend()
plt.show()

# %% [markdown]
# Конец. 🐟
