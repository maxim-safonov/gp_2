# %%
import pandas as pd

# %%
f1 = pd.read_csv('litres_171_255.csv')
f2 = pd.read_csv('litres_122_170.csv')
f3 = pd.read_csv('litres_94_170.csv')
f4 = pd.read_csv('litres_86_170.csv')
f5 = pd.read_csv('litres_430_500.csv')
f6 = pd.read_csv('litres_352_430.csv')
f7 = pd.read_csv('litres_344_352.csv')
f8 = pd.read_csv('litres_341_343.csv')
f9 = pd.read_csv('litres_256_340.csv')
f10 = pd.read_csv('litres_1_85 тест.csv')
f11 = pd.read_csv('litres_500_550.csv')

# %%
df = pd.concat(
    [f10, f4, f3, f2, f1, f9, f8, f7, f6, f5, f11],
    ignore_index=True
)

# %%
df = df[df['title'] != 'Your connection is not private']

# %%
df

# %%
df.to_csv('final.csv')
